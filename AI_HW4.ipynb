# %% [markdown]
# <a href="https://colab.research.google.com/github/mredelis/CAP4630-AI-Spr23/blob/main/AI_HW4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Recurrent Neural Network Homework
#
# This is the 4th assignment for CAP 4630 and we will implement a basic RNN network and an LSTM network with Keras to solve two problems. \
# You will use **"Tasks"** and **"Hints"** to finish the work. **(Total 100 points, including 15 bonus points)** \
# You may use Machine Learning libaries like Scikit-learn for data preprocessing.
#
# **Task Overview:**
# - Implement a basic RNN network to solve time series prediction
# - Implement an LSTM network to conduct sentiment analysis

# %% [markdown]
# ## 1 - Implement Basic RNN network with Keras to predict time series##
# ### 1.1 Prepare the data (17 Points)
#
# Prepare time series data for deep neural network training.
#
# **Tasks:**
# 1. Load the given train and test data: "train.txt" and "test.txt". **(5 Points)**
# 2. Generate the **TRAIN** and **TEST** labels. **(5 Points)**
# 3. Normalize the **TRAIN** and **TEST** data with sklearn function "MinMaxScaler". **(5 Points)**
# 4. **PRINT OUT** the **TEST** data and label. **(2 Points)**
#
# **Hints:**
# 1. The length of original train data is 113 which starts from **"1949-01"** to **"1958-05"**. The length of original test data is 29, which starts from **"1958-07"** to **"1960-11"**.
# 2. Set the data types of both train and test data to "float32".
# 3. When you prepared input data X (sequences) and output data Y (labels), please consider the following relationship:
#     - The sequence X should be the **past 12** datapoints in the time series, i.e., observation sequence with historical window of 12. You may check the time series data and think about the reason.
#     - The label Y should be the **next 1** datapoint in the time series (one point ahead prediction).
# 4. The first 3 **TRAIN** data and label should be:
#
# - trainX[0] = [[0.02203858 &nbsp; 0.03856748 &nbsp; 0.077135 &nbsp;  0.06887051 &nbsp; 0.04683197 &nbsp; 0.08539945 &nbsp; 0.12121212 &nbsp; 0.12121212 &nbsp; 0.08815429 &nbsp; 0.04132232 &nbsp; 0.    &nbsp; 0.03856748]]
# - trainY[0] = [0.03030303]
#
# - trianX[1] = [[0.03856748 &nbsp; 0.077135 &nbsp;  0.06887051 &nbsp; 0.04683197  &nbsp; 0.08539945  &nbsp; 0.12121212  &nbsp; 0.12121212  &nbsp; 0.08815429  &nbsp; 0.04132232  &nbsp; 0.     &nbsp;  0.03856748   &nbsp; 0.03030303]]
# - trainY[1] = [0.06060606]
#
# - trainX[2] =  [[0.077135 &nbsp;  0.06887051 &nbsp; 0.04683197 &nbsp; 0.08539945 &nbsp; 0.12121212 &nbsp; 0.12121212 &nbsp; 0.08815429 &nbsp; 0.04132232 &nbsp; 0.    &nbsp;     0.03856748 &nbsp; 0.03030303 &nbsp; 0.06060606]]
# - trainY[2] = [0.10192838]
#
# 5. Apply the MinMaxScaler to both the train and test data.\
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html
#
#
# 6. After the preparation with scaler fitting, the shapes of trainX, trainY, testX, and testY are as follows:\
# trainX.shape = (101, 1, 12)\
# trainY.shape = (101,)\
# testX.shape = (17, 1, 12)\
# testY.shape = (17,)

# %%
### Import Libraries ###
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import random
import numpy as np

# np.set_printoptions(linewidth=200)
np.set_printoptions(threshold=np.inf)

### Set random seed to ensure deterministic results
import os
seed_value = 1
os.environ['PYTHONHASHSEED']=str(seed_value)

def reset_random_seeds():
   tf.random.set_seed(seed_value)
   np.random.seed(seed_value)
   random.seed(seed_value)

reset_random_seeds()

# %%
### Prepare and Preprocess Data Here ###
from pandas import read_csv

### Design a Function to Prepare Observation Sequences and Corresponding Labels ###

# look_back is used to specify input sequence length
def create_dataset(dataset, look_back=12):
  dataX, dataY = [], []
  for i in range(len(dataset) - look_back):
   a = dataset[i:(i+look_back), 0]
   dataX.append(a)
   dataY.append(dataset[i+look_back, 0])
   
  return np.array(dataX), np.array(dataY)


### Train and Test Data Loading with float32 type ####

# Load .txt file from GitHub
url_train = "https://raw.githubusercontent.com/mredelis/CAP4630-AI-Spr23/main/train.txt"
url_test = "https://raw.githubusercontent.com/mredelis/CAP4630-AI-Spr23/main/test.txt"

dataframe_train = read_csv(url_train, usecols=[1], engine='python') # Read train.txt 
dataset_train = dataframe_train.values # extract the numpy array from the dataframe
dataset_train = dataset_train.astype('float32') # convert the int values to 'float32' which are more suitable for modeling with neural network
# print(dataset_train)
# print()

dataframe_test = read_csv(url_test, usecols=[1], engine='python')
dataset_test = dataframe_test.values
dataset_test = dataset_test.astype('float32')
# print(dataset_test)

### Scale Training and Test Data to [0, 1] ###
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1)) # specify the scaler
train = scaler.fit_transform(dataset_train) # fit the scaler to the training data
test = scaler.transform(dataset_test) # fit the scaler to the test data

### Training and Test Data Split ###
# Takes a numpy array to convert it into a dataset and look_back is the number of previous time steps 
# to use as input variables to predict the next time (t)
# X will be the number of passenger at a given time
# Y is the number of passengers at the next time (t + 12)
look_back=12
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# print(trainX.shape)
# print(trainY.shape)
# print()

### Training and Test Data Reshape (to fit RNN input) ###
# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

### Print Out the TEST Data and Labels Here ### It should be TRAIN not TEST
for i in range(len(trainX)):
  print(f"trainX[{i}] = {trainX[i]}\n")
  print(f"trainY[{i}] = {trainY[i]:.8f}\n")

print(f"trainX.shape = {trainX.shape}")
print(f"trainY.shape = {trainY.shape}")
print(f"testX.shape = {testX.shape}")
print(f"testY.shape = {testY.shape}")
# Out:
# trainX[0] = [[0.02203858 0.03856748 0.077135   0.06887051 0.04683197 0.08539945
#   0.12121212 0.12121212 0.08815429 0.04132232 0.         0.03856748]]
#
# trainY[0] = 0.03030303
#
# trainX[1] = [[0.03856748 0.077135   0.06887051 0.04683197 0.08539945 0.12121212
#   0.12121212 0.08815429 0.04132232 0.         0.03856748 0.03030303]]
#
# trainY[1] = 0.06060606
#
# trainX[2] = [[0.077135   0.06887051 0.04683197 0.08539945 0.12121212 0.12121212
#   0.08815429 0.04132232 0.         0.03856748 0.03030303 0.06060606]]
#
# trainY[2] = 0.10192838
#
# trainX[3] = [[0.06887051 0.04683197 0.08539945 0.12121212 0.12121212 0.08815429
#   0.04132232 0.         0.03856748 0.03030303 0.06060606 0.10192838]]
#
# trainY[3] = 0.08539945
#
# trainX[4] = [[0.04683197 0.08539945 0.12121212 0.12121212 0.08815429 0.04132232
#   0.         0.03856748 0.03030303 0.06060606 0.10192838 0.08539945]]
#
# trainY[4] = 0.05785125
#
# trainX[5] = [[0.08539945 0.12121212 0.12121212 0.08815429 0.04132232 0.
#   0.03856748 0.03030303 0.06060606 0.10192838 0.08539945 0.05785125]]
#
# trainY[5] = 0.12396696
#
# trainX[6] = [[0.12121212 0.12121212 0.08815429 0.04132232 0.         0.03856748
#   0.03030303 0.06060606 0.10192838 0.08539945 0.05785125 0.12396696]]
#
# trainY[6] = 0.18181819
#
# trainX[7] = [[0.12121212 0.08815429 0.04132232 0.         0.03856748 0.03030303
#   0.06060606 0.10192838 0.08539945 0.05785125 0.12396696 0.18181819]]
#
# trainY[7] = 0.18181819
#
# trainX[8] = [[0.08815429 0.04132232 0.         0.03856748 0.03030303 0.06060606
#   0.10192838 0.08539945 0.05785125 0.12396696 0.18181819 0.18181819]]
#
# trainY[8] = 0.14876035
#
# trainX[9] = [[0.04132232 0.         0.03856748 0.03030303 0.06060606 0.10192838
#   0.08539945 0.05785125 0.12396696 0.18181819 0.18181819 0.14876035]]
#
# trainY[9] = 0.07988980
#
# trainX[10] = [[0.         0.03856748 0.03030303 0.06060606 0.10192838 0.08539945
#   0.05785125 0.12396696 0.18181819 0.18181819 0.14876035 0.0798898 ]]
#
# trainY[10] = 0.02754822
#
# trainX[11] = [[0.03856748 0.03030303 0.06060606 0.10192838 0.08539945 0.05785125
#   0.12396696 0.18181819 0.18181819 0.14876035 0.0798898  0.02754822]]
#
# trainY[11] = 0.09917355
#
# trainX[12] = [[0.03030303 0.06060606 0.10192838 0.08539945 0.05785125 0.12396696
#   0.18181819 0.18181819 0.14876035 0.0798898  0.02754822 0.09917355]]
#
# trainY[12] = 0.11294767
#
# trainX[13] = [[0.06060606 0.10192838 0.08539945 0.05785125 0.12396696 0.18181819
#   0.18181819 0.14876035 0.0798898  0.02754822 0.09917355 0.11294767]]
#
# trainY[13] = 0.12672177
#
# trainX[14] = [[0.10192838 0.08539945 0.05785125 0.12396696 0.18181819 0.18181819
#   0.14876035 0.0798898  0.02754822 0.09917355 0.11294767 0.12672177]]
#
# trainY[14] = 0.20385677
#
# trainX[15] = [[0.08539945 0.05785125 0.12396696 0.18181819 0.18181819 0.14876035
#   0.0798898  0.02754822 0.09917355 0.11294767 0.12672177 0.20385677]]
#
# trainY[15] = 0.16253445
#
# trainX[16] = [[0.05785125 0.12396696 0.18181819 0.18181819 0.14876035 0.0798898
#   0.02754822 0.09917355 0.11294767 0.12672177 0.20385677 0.16253445]]
#
# trainY[16] = 0.18732783
#
# trainX[17] = [[0.12396696 0.18181819 0.18181819 0.14876035 0.0798898  0.02754822
#   0.09917355 0.11294767 0.12672177 0.20385677 0.16253445 0.18732783]]
#
# trainY[17] = 0.20385677
#
# trainX[18] = [[0.18181819 0.18181819 0.14876035 0.0798898  0.02754822 0.09917355
#   0.11294767 0.12672177 0.20385677 0.16253445 0.18732783 0.20385677]]
#
# trainY[18] = 0.26170799
#
# trainX[19] = [[0.18181819 0.14876035 0.0798898  0.02754822 0.09917355 0.11294767
#   0.12672177 0.20385677 0.16253445 0.18732783 0.20385677 0.261708  ]]
#
# trainY[19] = 0.26170799
#
# trainX[20] = [[0.14876035 0.0798898  0.02754822 0.09917355 0.11294767 0.12672177
#   0.20385677 0.16253445 0.18732783 0.20385677 0.261708   0.261708  ]]
#
# trainY[20] = 0.22038570
#
# trainX[21] = [[0.0798898  0.02754822 0.09917355 0.11294767 0.12672177 0.20385677
#   0.16253445 0.18732783 0.20385677 0.261708   0.261708   0.2203857 ]]
#
# trainY[21] = 0.15977961
#
# trainX[22] = [[0.02754822 0.09917355 0.11294767 0.12672177 0.20385677 0.16253445
#   0.18732783 0.20385677 0.261708   0.261708   0.2203857  0.15977961]]
#
# trainY[22] = 0.11570248
#
# trainX[23] = [[0.09917355 0.11294767 0.12672177 0.20385677 0.16253445 0.18732783
#   0.20385677 0.261708   0.261708   0.2203857  0.15977961 0.11570248]]
#
# trainY[23] = 0.17079890
#
# trainX[24] = [[0.11294767 0.12672177 0.20385677 0.16253445 0.18732783 0.20385677
#   0.261708   0.261708   0.2203857  0.15977961 0.11570248 0.1707989 ]]
#
# trainY[24] = 0.18457299
#
# trainX[25] = [[0.12672177 0.20385677 0.16253445 0.18732783 0.20385677 0.261708
#   0.261708   0.2203857  0.15977961 0.11570248 0.1707989  0.184573  ]]
#
# trainY[25] = 0.20936641
#
# trainX[26] = [[0.20385677 0.16253445 0.18732783 0.20385677 0.261708   0.261708
#   0.2203857  0.15977961 0.11570248 0.1707989  0.184573   0.20936641]]
#
# trainY[26] = 0.24517909
#
# trainX[27] = [[0.16253445 0.18732783 0.20385677 0.261708   0.261708   0.2203857
#   0.15977961 0.11570248 0.1707989  0.184573   0.20936641 0.24517909]]
#
# trainY[27] = 0.21212122
#
# trainX[28] = [[0.18732783 0.20385677 0.261708   0.261708   0.2203857  0.15977961
#   0.11570248 0.1707989  0.184573   0.20936641 0.24517909 0.21212122]]
#
# trainY[28] = 0.21763083
#
# trainX[29] = [[0.20385677 0.261708   0.261708   0.2203857  0.15977961 0.11570248
#   0.1707989  0.184573   0.20936641 0.24517909 0.21212122 0.21763083]]
#
# trainY[29] = 0.31404957
#
# trainX[30] = [[0.261708   0.261708   0.2203857  0.15977961 0.11570248 0.1707989
#   0.184573   0.20936641 0.24517909 0.21212122 0.21763083 0.31404957]]
#
# trainY[30] = 0.34710744
#
# trainX[31] = [[0.261708   0.2203857  0.15977961 0.11570248 0.1707989  0.184573
#   0.20936641 0.24517909 0.21212122 0.21763083 0.31404957 0.34710744]]
#
# trainY[31] = 0.38016531
#
# trainX[32] = [[0.2203857  0.15977961 0.11570248 0.1707989  0.184573   0.20936641
#   0.24517909 0.21212122 0.21763083 0.31404957 0.34710744 0.3801653 ]]
#
# trainY[32] = 0.28925619
#
# trainX[33] = [[0.15977961 0.11570248 0.1707989  0.184573   0.20936641 0.24517909
#   0.21212122 0.21763083 0.31404957 0.34710744 0.3801653  0.2892562 ]]
#
# trainY[33] = 0.23966941
#
# trainX[34] = [[0.11570248 0.1707989  0.184573   0.20936641 0.24517909 0.21212122
#   0.21763083 0.31404957 0.34710744 0.3801653  0.2892562  0.23966941]]
#
# trainY[34] = 0.18732783
#
# trainX[35] = [[0.1707989  0.184573   0.20936641 0.24517909 0.21212122 0.21763083
#   0.31404957 0.34710744 0.3801653  0.2892562  0.23966941 0.18732783]]
#
# trainY[35] = 0.24793389
#
# trainX[36] = [[0.184573   0.20936641 0.24517909 0.21212122 0.21763083 0.31404957
#   0.34710744 0.3801653  0.2892562  0.23966941 0.18732783 0.2479339 ]]
#
# trainY[36] = 0.25344351
#
# trainX[37] = [[0.20936641 0.24517909 0.21212122 0.21763083 0.31404957 0.34710744
#   0.3801653  0.2892562  0.23966941 0.18732783 0.2479339  0.2534435 ]]
#
# trainY[37] = 0.25344351
#
# trainX[38] = [[0.24517909 0.21212122 0.21763083 0.31404957 0.34710744 0.3801653
#   0.2892562  0.23966941 0.18732783 0.2479339  0.2534435  0.2534435 ]]
#
# trainY[38] = 0.36363634
#
# trainX[39] = [[0.21212122 0.21763083 0.31404957 0.34710744 0.3801653  0.2892562
#   0.23966941 0.18732783 0.2479339  0.2534435  0.2534435  0.36363634]]
#
# trainY[39] = 0.36088154
#
# trainX[40] = [[0.21763083 0.31404957 0.34710744 0.3801653  0.2892562  0.23966941
#   0.18732783 0.2479339  0.2534435  0.2534435  0.36363634 0.36088154]]
#
# trainY[40] = 0.34435263
#
# trainX[41] = [[0.31404957 0.34710744 0.3801653  0.2892562  0.23966941 0.18732783
#   0.2479339  0.2534435  0.2534435  0.36363634 0.36088154 0.34435263]]
#
# trainY[41] = 0.38292012
#
# trainX[42] = [[0.34710744 0.3801653  0.2892562  0.23966941 0.18732783 0.2479339
#   0.2534435  0.2534435  0.36363634 0.36088154 0.34435263 0.38292012]]
#
# trainY[42] = 0.44077137
#
# trainX[43] = [[0.3801653  0.2892562  0.23966941 0.18732783 0.2479339  0.2534435
#   0.2534435  0.36363634 0.36088154 0.34435263 0.38292012 0.44077137]]
#
# trainY[43] = 0.46280995
#
# trainX[44] = [[0.2892562  0.23966941 0.18732783 0.2479339  0.2534435  0.2534435
#   0.36363634 0.36088154 0.34435263 0.38292012 0.44077137 0.46280995]]
#
# trainY[44] = 0.36639121
#
# trainX[45] = [[0.23966941 0.18732783 0.2479339  0.2534435  0.2534435  0.36363634
#   0.36088154 0.34435263 0.38292012 0.44077137 0.46280995 0.3663912 ]]
#
# trainY[45] = 0.29476586
#
# trainX[46] = [[0.18732783 0.2479339  0.2534435  0.2534435  0.36363634 0.36088154
#   0.34435263 0.38292012 0.44077137 0.46280995 0.3663912  0.29476586]]
#
# trainY[46] = 0.20936641
#
# trainX[47] = [[0.2479339  0.2534435  0.2534435  0.36363634 0.36088154 0.34435263
#   0.38292012 0.44077137 0.46280995 0.3663912  0.29476586 0.20936641]]
#
# trainY[47] = 0.26721767
#
# trainX[48] = [[0.2534435  0.2534435  0.36363634 0.36088154 0.34435263 0.38292012
#   0.44077137 0.46280995 0.3663912  0.29476586 0.20936641 0.26721767]]
#
# trainY[48] = 0.27548209
#
# trainX[49] = [[0.2534435  0.36363634 0.36088154 0.34435263 0.38292012 0.44077137
#   0.46280995 0.3663912  0.29476586 0.20936641 0.26721767 0.2754821 ]]
#
# trainY[49] = 0.23140499
#
# trainX[50] = [[0.36363634 0.36088154 0.34435263 0.38292012 0.44077137 0.46280995
#   0.3663912  0.29476586 0.20936641 0.26721767 0.2754821  0.23140499]]
#
# trainY[50] = 0.36088154
#
# trainX[51] = [[0.36088154 0.34435263 0.38292012 0.44077137 0.46280995 0.3663912
#   0.29476586 0.20936641 0.26721767 0.2754821  0.23140499 0.36088154]]
#
# trainY[51] = 0.33884296
#
# trainX[52] = [[0.34435263 0.38292012 0.44077137 0.46280995 0.3663912  0.29476586
#   0.20936641 0.26721767 0.2754821  0.23140499 0.36088154 0.33884296]]
#
# trainY[52] = 0.35812673
#
# trainX[53] = [[0.38292012 0.44077137 0.46280995 0.3663912  0.29476586 0.20936641
#   0.26721767 0.2754821  0.23140499 0.36088154 0.33884296 0.35812673]]
#
# trainY[53] = 0.44077137
#
# trainX[54] = [[0.44077137 0.46280995 0.3663912  0.29476586 0.20936641 0.26721767
#   0.2754821  0.23140499 0.36088154 0.33884296 0.35812673 0.44077137]]
#
# trainY[54] = 0.54545450
#
# trainX[55] = [[0.46280995 0.3663912  0.29476586 0.20936641 0.26721767 0.2754821
#   0.23140499 0.36088154 0.33884296 0.35812673 0.44077137 0.5454545 ]]
#
# trainY[55] = 0.52066112
#
# trainX[56] = [[0.3663912  0.29476586 0.20936641 0.26721767 0.2754821  0.23140499
#   0.36088154 0.33884296 0.35812673 0.44077137 0.5454545  0.5206611 ]]
#
# trainY[56] = 0.42699727
#
# trainX[57] = [[0.29476586 0.20936641 0.26721767 0.2754821  0.23140499 0.36088154
#   0.33884296 0.35812673 0.44077137 0.5454545  0.5206611  0.42699727]]
#
# trainY[57] = 0.34435263
#
# trainX[58] = [[0.20936641 0.26721767 0.2754821  0.23140499 0.36088154 0.33884296
#   0.35812673 0.44077137 0.5454545  0.5206611  0.42699727 0.34435263]]
#
# trainY[58] = 0.27272728
#
# trainX[59] = [[0.26721767 0.2754821  0.23140499 0.36088154 0.33884296 0.35812673
#   0.44077137 0.5454545  0.5206611  0.42699727 0.34435263 0.27272728]]
#
# trainY[59] = 0.34435263
#
# trainX[60] = [[0.2754821  0.23140499 0.36088154 0.33884296 0.35812673 0.44077137
#   0.5454545  0.5206611  0.42699727 0.34435263 0.27272728 0.34435263]]
#
# trainY[60] = 0.38016531
#
# trainX[61] = [[0.23140499 0.36088154 0.33884296 0.35812673 0.44077137 0.5454545
#   0.5206611  0.42699727 0.34435263 0.27272728 0.34435263 0.3801653 ]]
#
# trainY[61] = 0.35537192
#
# trainX[62] = [[0.36088154 0.33884296 0.35812673 0.44077137 0.5454545  0.5206611
#   0.42699727 0.34435263 0.27272728 0.34435263 0.3801653  0.35537192]]
#
# trainY[62] = 0.44903579
#
# trainX[63] = [[0.33884296 0.35812673 0.44077137 0.5454545  0.5206611  0.42699727
#   0.34435263 0.27272728 0.34435263 0.3801653  0.35537192 0.4490358 ]]
#
# trainY[63] = 0.45454547
#
# trainX[64] = [[0.35812673 0.44077137 0.5454545  0.5206611  0.42699727 0.34435263
#   0.27272728 0.34435263 0.3801653  0.35537192 0.4490358  0.45454547]]
#
# trainY[64] = 0.45730028
#
# trainX[65] = [[0.44077137 0.5454545  0.5206611  0.42699727 0.34435263 0.27272728
#   0.34435263 0.3801653  0.35537192 0.4490358  0.45454547 0.45730028]]
#
# trainY[65] = 0.58126724
#
# trainX[66] = [[0.5454545  0.5206611  0.42699727 0.34435263 0.27272728 0.34435263
#   0.3801653  0.35537192 0.4490358  0.45454547 0.45730028 0.58126724]]
#
# trainY[66] = 0.71625340
#
# trainX[67] = [[0.5206611  0.42699727 0.34435263 0.27272728 0.34435263 0.3801653
#   0.35537192 0.4490358  0.45454547 0.45730028 0.58126724 0.7162534 ]]
#
# trainY[67] = 0.66942155
#
# trainX[68] = [[0.42699727 0.34435263 0.27272728 0.34435263 0.3801653  0.35537192
#   0.4490358  0.45454547 0.45730028 0.58126724 0.7162534  0.66942155]]
#
# trainY[68] = 0.57300282
#
# trainX[69] = [[0.34435263 0.27272728 0.34435263 0.3801653  0.35537192 0.4490358
#   0.45454547 0.45730028 0.58126724 0.7162534  0.66942155 0.5730028 ]]
#
# trainY[69] = 0.46831957
#
# trainX[70] = [[0.27272728 0.34435263 0.3801653  0.35537192 0.4490358  0.45454547
#   0.45730028 0.58126724 0.7162534  0.66942155 0.5730028  0.46831957]]
#
# trainY[70] = 0.36639121
#
# trainX[71] = [[0.34435263 0.3801653  0.35537192 0.4490358  0.45454547 0.45730028
#   0.58126724 0.7162534  0.66942155 0.5730028  0.46831957 0.3663912 ]]
#
# trainY[71] = 0.47933885
#
# trainX[72] = [[0.3801653  0.35537192 0.4490358  0.45454547 0.45730028 0.58126724
#   0.7162534  0.66942155 0.5730028  0.46831957 0.3663912  0.47933885]]
#
# trainY[72] = 0.49586776
#
# trainX[73] = [[0.35537192 0.4490358  0.45454547 0.45730028 0.58126724 0.7162534
#   0.66942155 0.5730028  0.46831957 0.3663912  0.47933885 0.49586776]]
#
# trainY[73] = 0.47658405
#
# trainX[74] = [[0.4490358  0.45454547 0.45730028 0.58126724 0.7162534  0.66942155
#   0.5730028  0.46831957 0.3663912  0.47933885 0.49586776 0.47658405]]
#
# trainY[74] = 0.58677685
#
# trainX[75] = [[0.45454547 0.45730028 0.58126724 0.7162534  0.66942155 0.5730028
#   0.46831957 0.3663912  0.47933885 0.49586776 0.47658405 0.58677685]]
#
# trainY[75] = 0.57575762
#
# trainX[76] = [[0.45730028 0.58126724 0.7162534  0.66942155 0.5730028  0.46831957
#   0.3663912  0.47933885 0.49586776 0.47658405 0.58677685 0.5757576 ]]
#
# trainY[76] = 0.58953166
#
# trainX[77] = [[0.58126724 0.7162534  0.66942155 0.5730028  0.46831957 0.3663912
#   0.47933885 0.49586776 0.47658405 0.58677685 0.5757576  0.58953166]]
#
# trainY[77] = 0.74380159
#
# trainX[78] = [[0.7162534  0.66942155 0.5730028  0.46831957 0.3663912  0.47933885
#   0.49586776 0.47658405 0.58677685 0.5757576  0.58953166 0.7438016 ]]
#
# trainY[78] = 0.85123968
#
# trainX[79] = [[0.66942155 0.5730028  0.46831957 0.3663912  0.47933885 0.49586776
#   0.47658405 0.58677685 0.5757576  0.58953166 0.7438016  0.8512397 ]]
#
# trainY[79] = 0.82920110
#
# trainX[80] = [[0.5730028  0.46831957 0.3663912  0.47933885 0.49586776 0.47658405
#   0.58677685 0.5757576  0.58953166 0.7438016  0.8512397  0.8292011 ]]
#
# trainY[80] = 0.69146001
#
# trainX[81] = [[0.46831957 0.3663912  0.47933885 0.49586776 0.47658405 0.58677685
#   0.5757576  0.58953166 0.7438016  0.8512397  0.8292011  0.69146   ]]
#
# trainY[81] = 0.55647385
#
# trainX[82] = [[0.3663912  0.47933885 0.49586776 0.47658405 0.58677685 0.5757576
#   0.58953166 0.7438016  0.8512397  0.8292011  0.69146    0.55647385]]
#
# trainY[82] = 0.46005508
#
# trainX[83] = [[0.47933885 0.49586776 0.47658405 0.58677685 0.5757576  0.58953166
#   0.7438016  0.8512397  0.8292011  0.69146    0.55647385 0.46005508]]
#
# trainY[83] = 0.55647385
#
# trainX[84] = [[0.49586776 0.47658405 0.58677685 0.5757576  0.58953166 0.7438016
#   0.8512397  0.8292011  0.69146    0.55647385 0.46005508 0.55647385]]
#
# trainY[84] = 0.58126724
#
# trainX[85] = [[0.47658405 0.58677685 0.5757576  0.58953166 0.7438016  0.8512397
#   0.8292011  0.69146    0.55647385 0.46005508 0.55647385 0.58126724]]
#
# trainY[85] = 0.54269969
#
# trainX[86] = [[0.58677685 0.5757576  0.58953166 0.7438016  0.8512397  0.8292011
#   0.69146    0.55647385 0.46005508 0.55647385 0.58126724 0.5426997 ]]
#
# trainY[86] = 0.69421494
#
# trainX[87] = [[0.5757576  0.58953166 0.7438016  0.8512397  0.8292011  0.69146
#   0.55647385 0.46005508 0.55647385 0.58126724 0.5426997  0.69421494]]
#
# trainY[87] = 0.67217636
#
# trainX[88] = [[0.58953166 0.7438016  0.8512397  0.8292011  0.69146    0.55647385
#   0.46005508 0.55647385 0.58126724 0.5426997  0.69421494 0.67217636]]
#
# trainY[88] = 0.69146001
#
# trainX[89] = [[0.7438016  0.8512397  0.8292011  0.69146    0.55647385 0.46005508
#   0.55647385 0.58126724 0.5426997  0.69421494 0.67217636 0.69146   ]]
#
# trainY[89] = 0.87603307
#
# trainX[90] = [[0.8512397  0.8292011  0.69146    0.55647385 0.46005508 0.55647385
#   0.58126724 0.5426997  0.69421494 0.67217636 0.69146    0.87603307]]
#
# trainY[90] = 0.99449039
#
# trainX[91] = [[0.8292011  0.69146    0.55647385 0.46005508 0.55647385 0.58126724
#   0.5426997  0.69421494 0.67217636 0.69146    0.87603307 0.9944904 ]]
#
# trainY[91] = 1.00000000
#
# trainX[92] = [[0.69146    0.55647385 0.46005508 0.55647385 0.58126724 0.5426997
#   0.69421494 0.67217636 0.69146    0.87603307 0.9944904  1.        ]]
#
# trainY[92] = 0.82644629
#
# trainX[93] = [[0.55647385 0.46005508 0.55647385 0.58126724 0.5426997  0.69421494
#   0.67217636 0.69146    0.87603307 0.9944904  1.         0.8264463 ]]
#
# trainY[93] = 0.66942155
#
# trainX[94] = [[0.46005508 0.55647385 0.58126724 0.5426997  0.69421494 0.67217636
#   0.69146    0.87603307 0.9944904  1.         0.8264463  0.66942155]]
#
# trainY[94] = 0.55371904
#
# trainX[95] = [[0.55647385 0.58126724 0.5426997  0.69421494 0.67217636 0.69146
#   0.87603307 0.9944904  1.         0.8264463  0.66942155 0.55371904]]
#
# trainY[95] = 0.63911843
#
# trainX[96] = [[0.58126724 0.5426997  0.69421494 0.67217636 0.69146    0.87603307
#   0.9944904  1.         0.8264463  0.66942155 0.55371904 0.63911843]]
#
# trainY[96] = 0.65013778
#
# trainX[97] = [[0.5426997  0.69421494 0.67217636 0.69146    0.87603307 0.9944904
#   1.         0.8264463  0.66942155 0.55371904 0.63911843 0.6501378 ]]
#
# trainY[97] = 0.58953166
#
# trainX[98] = [[0.69421494 0.67217636 0.69146    0.87603307 0.9944904  1.
#   0.8264463  0.66942155 0.55371904 0.63911843 0.6501378  0.58953166]]
#
# trainY[98] = 0.71074378
#
# trainX[99] = [[0.67217636 0.69146    0.87603307 0.9944904  1.         0.8264463
#   0.66942155 0.55371904 0.63911843 0.6501378  0.58953166 0.7107438 ]]
#
# trainY[99] = 0.67217636
#
# trainX[100] = [[0.69146    0.87603307 0.9944904  1.         0.8264463  0.66942155
#   0.55371904 0.63911843 0.6501378  0.58953166 0.7107438  0.67217636]]
#
# trainY[100] = 0.71349859
#
# trainX.shape = (101, 1, 12)
# trainY.shape = (101,)
# testX.shape = (17, 1, 12)
# testY.shape = (17,)

# %% [markdown]
# ### 1.2 - Build the RNN model (20 Points) ##
#
#
# Build an RNN model with SimpleRNN cell.
#
# **Tasks:**
# 1. Build an RNN model with 1 simple RNN layer and 1 Dense layer.  **(10 Points)**
# 2. Compile the model. **(5 Points)**
# 3. Train the model for **1000** epochs with **batch_size = 10**. **(5 Points)**
#
# **Hints:**
# 1. You may consider **tensorflow.keras.layers.SimpleRNN(unit_size=4)** to specify RNN cells.
# 2. Use loss function = 'mean_squared_error' and select **Adam** optimizer with **learning_rate=0.005** and other default settings.
# 3. After first epoch, the train loss is changed to around **0.0912**.
# 4. The model summary is as follows:
# - Total params: 73
# - Trainable params: 73
# - Non-trainable params: 0

# %%
### Build the RNN Model ###
import keras
from keras.models import Sequential

keras.backend.clear_session()

model = Sequential() # Declare Sequential class and assign it to variable "model"
model.add(keras.layers.SimpleRNN(units=4, input_shape=(1, look_back))) # Add a simple RNN layer with unit_size=4 in the model 
model.add(keras.layers.Dense(units=1)) # Add a following Dense layer with units=1 in the model 

### Compile the RNN Model  ###
opt = keras.optimizers.Adam(learning_rate=0.005)
model.compile(optimizer = 'adam', loss = 'mean_squared_error') # model compiled with mean_squared_error loss and adam optimizer

### Train the RNN Model  ###
model.fit(trainX, trainY, epochs=1000, batch_size=10, verbose=2) # model fit with epoch=1000, batch_size=10; verbose=2 is optional.
model.summary() # print out model structure with model.summary()
# Out:
# Epoch 1/1000
# 11/11 - 9s - loss: 0.0943 - 9s/epoch - 830ms/step
# Epoch 2/1000
# 11/11 - 0s - loss: 0.0518 - 92ms/epoch - 8ms/step
# Epoch 3/1000
# 11/11 - 0s - loss: 0.0470 - 72ms/epoch - 7ms/step
# Epoch 4/1000
# 11/11 - 0s - loss: 0.0452 - 49ms/epoch - 4ms/step
# Epoch 5/1000
# 11/11 - 0s - loss: 0.0427 - 81ms/epoch - 7ms/step
# Epoch 6/1000
# 11/11 - 0s - loss: 0.0411 - 57ms/epoch - 5ms/step
# Epoch 7/1000
# 11/11 - 0s - loss: 0.0395 - 77ms/epoch - 7ms/step
# Epoch 8/1000
# 11/11 - 0s - loss: 0.0383 - 78ms/epoch - 7ms/step
# Epoch 9/1000
# 11/11 - 0s - loss: 0.0366 - 65ms/epoch - 6ms/step
# Epoch 10/1000
# 11/11 - 0s - loss: 0.0350 - 57ms/epoch - 5ms/step
# Epoch 11/1000
# 11/11 - 0s - loss: 0.0337 - 75ms/epoch - 7ms/step
# Epoch 12/1000
# 11/11 - 0s - loss: 0.0320 - 87ms/epoch - 8ms/step
# Epoch 13/1000
# 11/11 - 0s - loss: 0.0319 - 39ms/epoch - 4ms/step
# Epoch 14/1000
# 11/11 - 0s - loss: 0.0300 - 37ms/epoch - 3ms/step
# Epoch 15/1000
# 11/11 - 0s - loss: 0.0289 - 37ms/epoch - 3ms/step
# Epoch 16/1000
# 11/11 - 0s - loss: 0.0282 - 46ms/epoch - 4ms/step
# Epoch 17/1000
# 11/11 - 0s - loss: 0.0275 - 43ms/epoch - 4ms/step
# Epoch 18/1000
# 11/11 - 0s - loss: 0.0263 - 40ms/epoch - 4ms/step
# Epoch 19/1000
# 11/11 - 0s - loss: 0.0255 - 37ms/epoch - 3ms/step
# Epoch 20/1000
# 11/11 - 0s - loss: 0.0250 - 37ms/epoch - 3ms/step
# Epoch 21/1000
# 11/11 - 0s - loss: 0.0239 - 37ms/epoch - 3ms/step
# Epoch 22/1000
# 11/11 - 0s - loss: 0.0231 - 45ms/epoch - 4ms/step
# Epoch 23/1000
# 11/11 - 0s - loss: 0.0226 - 38ms/epoch - 3ms/step
# Epoch 24/1000
# 11/11 - 0s - loss: 0.0218 - 45ms/epoch - 4ms/step
# Epoch 25/1000
# 11/11 - 0s - loss: 0.0214 - 38ms/epoch - 3ms/step
# Epoch 26/1000
# 11/11 - 0s - loss: 0.0206 - 39ms/epoch - 4ms/step
# Epoch 27/1000
# 11/11 - 0s - loss: 0.0203 - 37ms/epoch - 3ms/step
# Epoch 28/1000
# 11/11 - 0s - loss: 0.0203 - 38ms/epoch - 3ms/step
# Epoch 29/1000
# 11/11 - 0s - loss: 0.0191 - 47ms/epoch - 4ms/step
# Epoch 30/1000
# 11/11 - 0s - loss: 0.0181 - 38ms/epoch - 3ms/step
# Epoch 31/1000
# 11/11 - 0s - loss: 0.0178 - 36ms/epoch - 3ms/step
# Epoch 32/1000
# 11/11 - 0s - loss: 0.0175 - 37ms/epoch - 3ms/step
# Epoch 33/1000
# 11/11 - 0s - loss: 0.0170 - 45ms/epoch - 4ms/step
# Epoch 34/1000
# 11/11 - 0s - loss: 0.0167 - 58ms/epoch - 5ms/step
# Epoch 35/1000
# 11/11 - 0s - loss: 0.0162 - 37ms/epoch - 3ms/step
# Epoch 36/1000
# 11/11 - 0s - loss: 0.0158 - 38ms/epoch - 3ms/step
# Epoch 37/1000
# 11/11 - 0s - loss: 0.0155 - 39ms/epoch - 4ms/step
# Epoch 38/1000
# 11/11 - 0s - loss: 0.0155 - 38ms/epoch - 3ms/step
# Epoch 39/1000
# 11/11 - 0s - loss: 0.0156 - 36ms/epoch - 3ms/step
# Epoch 40/1000
# 11/11 - 0s - loss: 0.0149 - 39ms/epoch - 4ms/step
# Epoch 41/1000
# 11/11 - 0s - loss: 0.0142 - 37ms/epoch - 3ms/step
# Epoch 42/1000
# 11/11 - 0s - loss: 0.0138 - 41ms/epoch - 4ms/step
# Epoch 43/1000
# 11/11 - 0s - loss: 0.0136 - 42ms/epoch - 4ms/step
# Epoch 44/1000
# 11/11 - 0s - loss: 0.0134 - 39ms/epoch - 4ms/step
# Epoch 45/1000
# 11/11 - 0s - loss: 0.0130 - 46ms/epoch - 4ms/step
# Epoch 46/1000
# 11/11 - 0s - loss: 0.0130 - 37ms/epoch - 3ms/step
# Epoch 47/1000
# 11/11 - 0s - loss: 0.0125 - 43ms/epoch - 4ms/step
# Epoch 48/1000
# 11/11 - 0s - loss: 0.0125 - 39ms/epoch - 4ms/step
# Epoch 49/1000
# 11/11 - 0s - loss: 0.0122 - 37ms/epoch - 3ms/step
# Epoch 50/1000
# 11/11 - 0s - loss: 0.0123 - 37ms/epoch - 3ms/step
# Epoch 51/1000
# 11/11 - 0s - loss: 0.0120 - 38ms/epoch - 3ms/step
# Epoch 52/1000
# 11/11 - 0s - loss: 0.0116 - 46ms/epoch - 4ms/step
# Epoch 53/1000
# 11/11 - 0s - loss: 0.0114 - 39ms/epoch - 4ms/step
# Epoch 54/1000
# 11/11 - 0s - loss: 0.0112 - 38ms/epoch - 3ms/step
# Epoch 55/1000
# 11/11 - 0s - loss: 0.0112 - 40ms/epoch - 4ms/step
# Epoch 56/1000
# 11/11 - 0s - loss: 0.0110 - 38ms/epoch - 3ms/step
# Epoch 57/1000
# 11/11 - 0s - loss: 0.0108 - 43ms/epoch - 4ms/step
# Epoch 58/1000
# 11/11 - 0s - loss: 0.0108 - 38ms/epoch - 3ms/step
# Epoch 59/1000
# 11/11 - 0s - loss: 0.0106 - 38ms/epoch - 3ms/step
# Epoch 60/1000
# 11/11 - 0s - loss: 0.0104 - 37ms/epoch - 3ms/step
# Epoch 61/1000
# 11/11 - 0s - loss: 0.0103 - 38ms/epoch - 3ms/step
# Epoch 62/1000
# 11/11 - 0s - loss: 0.0101 - 38ms/epoch - 3ms/step
# Epoch 63/1000
# 11/11 - 0s - loss: 0.0101 - 36ms/epoch - 3ms/step
# Epoch 64/1000
# 11/11 - 0s - loss: 0.0097 - 39ms/epoch - 4ms/step
# Epoch 65/1000
# 11/11 - 0s - loss: 0.0097 - 37ms/epoch - 3ms/step
# Epoch 66/1000
# 11/11 - 0s - loss: 0.0095 - 37ms/epoch - 3ms/step
# Epoch 67/1000
# 11/11 - 0s - loss: 0.0094 - 39ms/epoch - 4ms/step
# Epoch 68/1000
# 11/11 - 0s - loss: 0.0092 - 40ms/epoch - 4ms/step
# Epoch 69/1000
# 11/11 - 0s - loss: 0.0090 - 48ms/epoch - 4ms/step
# Epoch 70/1000
# 11/11 - 0s - loss: 0.0096 - 42ms/epoch - 4ms/step
# Epoch 71/1000
# 11/11 - 0s - loss: 0.0091 - 39ms/epoch - 4ms/step
# Epoch 72/1000
# 11/11 - 0s - loss: 0.0090 - 39ms/epoch - 4ms/step
# Epoch 73/1000
# 11/11 - 0s - loss: 0.0088 - 40ms/epoch - 4ms/step
# Epoch 74/1000
# 11/11 - 0s - loss: 0.0089 - 47ms/epoch - 4ms/step
# Epoch 75/1000
# 11/11 - 0s - loss: 0.0088 - 41ms/epoch - 4ms/step
# Epoch 76/1000
# 11/11 - 0s - loss: 0.0089 - 37ms/epoch - 3ms/step
# Epoch 77/1000
# 11/11 - 0s - loss: 0.0088 - 37ms/epoch - 3ms/step
# Epoch 78/1000
# 11/11 - 0s - loss: 0.0082 - 38ms/epoch - 3ms/step
# Epoch 79/1000
# 11/11 - 0s - loss: 0.0083 - 46ms/epoch - 4ms/step
# Epoch 80/1000
# 11/11 - 0s - loss: 0.0082 - 38ms/epoch - 3ms/step
# Epoch 81/1000
# 11/11 - 0s - loss: 0.0080 - 38ms/epoch - 3ms/step
# Epoch 82/1000
# 11/11 - 0s - loss: 0.0083 - 37ms/epoch - 3ms/step
# Epoch 83/1000
# 11/11 - 0s - loss: 0.0080 - 38ms/epoch - 3ms/step
# Epoch 84/1000
# 11/11 - 0s - loss: 0.0083 - 38ms/epoch - 3ms/step
# Epoch 85/1000
# 11/11 - 0s - loss: 0.0081 - 39ms/epoch - 4ms/step
# Epoch 86/1000
# 11/11 - 0s - loss: 0.0075 - 46ms/epoch - 4ms/step
# Epoch 87/1000
# 11/11 - 0s - loss: 0.0078 - 43ms/epoch - 4ms/step
# Epoch 88/1000
# 11/11 - 0s - loss: 0.0078 - 40ms/epoch - 4ms/step
# Epoch 89/1000
# 11/11 - 0s - loss: 0.0074 - 41ms/epoch - 4ms/step
# Epoch 90/1000
# 11/11 - 0s - loss: 0.0073 - 40ms/epoch - 4ms/step
# Epoch 91/1000
# 11/11 - 0s - loss: 0.0073 - 46ms/epoch - 4ms/step
# Epoch 92/1000
# 11/11 - 0s - loss: 0.0072 - 38ms/epoch - 3ms/step
# Epoch 93/1000
# 11/11 - 0s - loss: 0.0070 - 46ms/epoch - 4ms/step
# Epoch 94/1000
# 11/11 - 0s - loss: 0.0074 - 37ms/epoch - 3ms/step
# Epoch 95/1000
# 11/11 - 0s - loss: 0.0070 - 37ms/epoch - 3ms/step
# Epoch 96/1000
# 11/11 - 0s - loss: 0.0072 - 37ms/epoch - 3ms/step
# Epoch 97/1000
# 11/11 - 0s - loss: 0.0071 - 37ms/epoch - 3ms/step
# Epoch 98/1000
# 11/11 - 0s - loss: 0.0069 - 43ms/epoch - 4ms/step
# Epoch 99/1000
# 11/11 - 0s - loss: 0.0069 - 37ms/epoch - 3ms/step
# Epoch 100/1000
# 11/11 - 0s - loss: 0.0070 - 43ms/epoch - 4ms/step
# Epoch 101/1000
# 11/11 - 0s - loss: 0.0067 - 41ms/epoch - 4ms/step
# Epoch 102/1000
# 11/11 - 0s - loss: 0.0067 - 44ms/epoch - 4ms/step
# Epoch 103/1000
# 11/11 - 0s - loss: 0.0066 - 39ms/epoch - 4ms/step
# Epoch 104/1000
# 11/11 - 0s - loss: 0.0066 - 41ms/epoch - 4ms/step
# Epoch 105/1000
# 11/11 - 0s - loss: 0.0065 - 38ms/epoch - 3ms/step
# Epoch 106/1000
# 11/11 - 0s - loss: 0.0066 - 36ms/epoch - 3ms/step
# Epoch 107/1000
# 11/11 - 0s - loss: 0.0064 - 38ms/epoch - 3ms/step
# Epoch 108/1000
# 11/11 - 0s - loss: 0.0064 - 36ms/epoch - 3ms/step
# Epoch 109/1000
# 11/11 - 0s - loss: 0.0063 - 45ms/epoch - 4ms/step
# Epoch 110/1000
# 11/11 - 0s - loss: 0.0063 - 39ms/epoch - 4ms/step
# Epoch 111/1000
# 11/11 - 0s - loss: 0.0063 - 39ms/epoch - 4ms/step
# Epoch 112/1000
# 11/11 - 0s - loss: 0.0062 - 38ms/epoch - 3ms/step
# Epoch 113/1000
# 11/11 - 0s - loss: 0.0061 - 36ms/epoch - 3ms/step
# Epoch 114/1000
# 11/11 - 0s - loss: 0.0061 - 38ms/epoch - 3ms/step
# Epoch 115/1000
# 11/11 - 0s - loss: 0.0061 - 38ms/epoch - 3ms/step
# Epoch 116/1000
# 11/11 - 0s - loss: 0.0060 - 38ms/epoch - 3ms/step
# Epoch 117/1000
# 11/11 - 0s - loss: 0.0060 - 46ms/epoch - 4ms/step
# Epoch 118/1000
# 11/11 - 0s - loss: 0.0059 - 37ms/epoch - 3ms/step
# Epoch 119/1000
# 11/11 - 0s - loss: 0.0059 - 41ms/epoch - 4ms/step
# Epoch 120/1000
# 11/11 - 0s - loss: 0.0058 - 40ms/epoch - 4ms/step
# Epoch 121/1000
# 11/11 - 0s - loss: 0.0061 - 46ms/epoch - 4ms/step
# Epoch 122/1000
# 11/11 - 0s - loss: 0.0059 - 38ms/epoch - 3ms/step
# Epoch 123/1000
# 11/11 - 0s - loss: 0.0058 - 39ms/epoch - 4ms/step
# Epoch 124/1000
# 11/11 - 0s - loss: 0.0058 - 38ms/epoch - 3ms/step
# Epoch 125/1000
# 11/11 - 0s - loss: 0.0058 - 38ms/epoch - 3ms/step
# Epoch 126/1000
# 11/11 - 0s - loss: 0.0057 - 38ms/epoch - 3ms/step
# Epoch 127/1000
# 11/11 - 0s - loss: 0.0057 - 44ms/epoch - 4ms/step
# Epoch 128/1000
# 11/11 - 0s - loss: 0.0057 - 37ms/epoch - 3ms/step
# Epoch 129/1000
# 11/11 - 0s - loss: 0.0055 - 39ms/epoch - 4ms/step
# Epoch 130/1000
# 11/11 - 0s - loss: 0.0054 - 39ms/epoch - 4ms/step
# Epoch 131/1000
# 11/11 - 0s - loss: 0.0055 - 46ms/epoch - 4ms/step
# Epoch 132/1000
# 11/11 - 0s - loss: 0.0055 - 36ms/epoch - 3ms/step
# Epoch 133/1000
# 11/11 - 0s - loss: 0.0053 - 38ms/epoch - 3ms/step
# Epoch 134/1000
# 11/11 - 0s - loss: 0.0056 - 38ms/epoch - 3ms/step
# Epoch 135/1000
# 11/11 - 0s - loss: 0.0053 - 39ms/epoch - 4ms/step
# Epoch 136/1000
# 11/11 - 0s - loss: 0.0054 - 43ms/epoch - 4ms/step
# Epoch 137/1000
# 11/11 - 0s - loss: 0.0053 - 37ms/epoch - 3ms/step
# Epoch 138/1000
# 11/11 - 0s - loss: 0.0052 - 39ms/epoch - 4ms/step
# Epoch 139/1000
# 11/11 - 0s - loss: 0.0052 - 39ms/epoch - 4ms/step
# Epoch 140/1000
# 11/11 - 0s - loss: 0.0052 - 52ms/epoch - 5ms/step
# Epoch 141/1000
# 11/11 - 0s - loss: 0.0053 - 38ms/epoch - 3ms/step
# Epoch 142/1000
# 11/11 - 0s - loss: 0.0053 - 41ms/epoch - 4ms/step
# Epoch 143/1000
# 11/11 - 0s - loss: 0.0052 - 39ms/epoch - 4ms/step
# Epoch 144/1000
# 11/11 - 0s - loss: 0.0051 - 38ms/epoch - 3ms/step
# Epoch 145/1000
# 11/11 - 0s - loss: 0.0050 - 40ms/epoch - 4ms/step
# Epoch 146/1000
# 11/11 - 0s - loss: 0.0050 - 45ms/epoch - 4ms/step
# Epoch 147/1000
# 11/11 - 0s - loss: 0.0049 - 39ms/epoch - 4ms/step
# Epoch 148/1000
# 11/11 - 0s - loss: 0.0049 - 39ms/epoch - 4ms/step
# Epoch 149/1000
# 11/11 - 0s - loss: 0.0052 - 37ms/epoch - 3ms/step
# Epoch 150/1000
# 11/11 - 0s - loss: 0.0050 - 37ms/epoch - 3ms/step
# Epoch 151/1000
# 11/11 - 0s - loss: 0.0049 - 38ms/epoch - 3ms/step
# Epoch 152/1000
# 11/11 - 0s - loss: 0.0049 - 46ms/epoch - 4ms/step
# Epoch 153/1000
# 11/11 - 0s - loss: 0.0048 - 38ms/epoch - 3ms/step
# Epoch 154/1000
# 11/11 - 0s - loss: 0.0048 - 37ms/epoch - 3ms/step
# Epoch 155/1000
# 11/11 - 0s - loss: 0.0048 - 38ms/epoch - 3ms/step
# Epoch 156/1000
# 11/11 - 0s - loss: 0.0047 - 39ms/epoch - 4ms/step
# Epoch 157/1000
# 11/11 - 0s - loss: 0.0047 - 40ms/epoch - 4ms/step
# Epoch 158/1000
# 11/11 - 0s - loss: 0.0047 - 38ms/epoch - 3ms/step
# Epoch 159/1000
# 11/11 - 0s - loss: 0.0047 - 38ms/epoch - 3ms/step
# Epoch 160/1000
# 11/11 - 0s - loss: 0.0046 - 45ms/epoch - 4ms/step
# Epoch 161/1000
# 11/11 - 0s - loss: 0.0046 - 36ms/epoch - 3ms/step
# Epoch 162/1000
# 11/11 - 0s - loss: 0.0047 - 39ms/epoch - 4ms/step
# Epoch 163/1000
# 11/11 - 0s - loss: 0.0046 - 37ms/epoch - 3ms/step
# Epoch 164/1000
# 11/11 - 0s - loss: 0.0045 - 47ms/epoch - 4ms/step
# Epoch 165/1000
# 11/11 - 0s - loss: 0.0045 - 41ms/epoch - 4ms/step
# Epoch 166/1000
# 11/11 - 0s - loss: 0.0044 - 40ms/epoch - 4ms/step
# Epoch 167/1000
# 11/11 - 0s - loss: 0.0044 - 38ms/epoch - 3ms/step
# Epoch 168/1000
# 11/11 - 0s - loss: 0.0045 - 39ms/epoch - 4ms/step
# Epoch 169/1000
# 11/11 - 0s - loss: 0.0044 - 44ms/epoch - 4ms/step
# Epoch 170/1000
# 11/11 - 0s - loss: 0.0044 - 37ms/epoch - 3ms/step
# Epoch 171/1000
# 11/11 - 0s - loss: 0.0044 - 39ms/epoch - 4ms/step
# Epoch 172/1000
# 11/11 - 0s - loss: 0.0043 - 40ms/epoch - 4ms/step
# Epoch 173/1000
# 11/11 - 0s - loss: 0.0048 - 38ms/epoch - 3ms/step
# Epoch 174/1000
# 11/11 - 0s - loss: 0.0043 - 46ms/epoch - 4ms/step
# Epoch 175/1000
# 11/11 - 0s - loss: 0.0046 - 55ms/epoch - 5ms/step
# Epoch 176/1000
# 11/11 - 0s - loss: 0.0042 - 42ms/epoch - 4ms/step
# Epoch 177/1000
# 11/11 - 0s - loss: 0.0042 - 42ms/epoch - 4ms/step
# Epoch 178/1000
# 11/11 - 0s - loss: 0.0043 - 42ms/epoch - 4ms/step
# Epoch 179/1000
# 11/11 - 0s - loss: 0.0042 - 39ms/epoch - 4ms/step
# Epoch 180/1000
# 11/11 - 0s - loss: 0.0042 - 40ms/epoch - 4ms/step
# Epoch 181/1000
# 11/11 - 0s - loss: 0.0041 - 39ms/epoch - 4ms/step
# Epoch 182/1000
# 11/11 - 0s - loss: 0.0043 - 38ms/epoch - 3ms/step
# Epoch 183/1000
# 11/11 - 0s - loss: 0.0043 - 45ms/epoch - 4ms/step
# Epoch 184/1000
# 11/11 - 0s - loss: 0.0041 - 37ms/epoch - 3ms/step
# Epoch 185/1000
# 11/11 - 0s - loss: 0.0041 - 39ms/epoch - 4ms/step
# Epoch 186/1000
# 11/11 - 0s - loss: 0.0041 - 37ms/epoch - 3ms/step
# Epoch 187/1000
# 11/11 - 0s - loss: 0.0041 - 49ms/epoch - 4ms/step
# Epoch 188/1000
# 11/11 - 0s - loss: 0.0041 - 42ms/epoch - 4ms/step
# Epoch 189/1000
# 11/11 - 0s - loss: 0.0039 - 39ms/epoch - 4ms/step
# Epoch 190/1000
# 11/11 - 0s - loss: 0.0040 - 37ms/epoch - 3ms/step
# Epoch 191/1000
# 11/11 - 0s - loss: 0.0041 - 37ms/epoch - 3ms/step
# Epoch 192/1000
# 11/11 - 0s - loss: 0.0039 - 44ms/epoch - 4ms/step
# Epoch 193/1000
# 11/11 - 0s - loss: 0.0039 - 39ms/epoch - 4ms/step
# Epoch 194/1000
# 11/11 - 0s - loss: 0.0038 - 37ms/epoch - 3ms/step
# Epoch 195/1000
# 11/11 - 0s - loss: 0.0040 - 37ms/epoch - 3ms/step
# Epoch 196/1000
# 11/11 - 0s - loss: 0.0039 - 44ms/epoch - 4ms/step
# Epoch 197/1000
# 11/11 - 0s - loss: 0.0040 - 37ms/epoch - 3ms/step
# Epoch 198/1000
# 11/11 - 0s - loss: 0.0039 - 39ms/epoch - 4ms/step
# Epoch 199/1000
# 11/11 - 0s - loss: 0.0042 - 39ms/epoch - 4ms/step
# Epoch 200/1000
# 11/11 - 0s - loss: 0.0041 - 37ms/epoch - 3ms/step
# Epoch 201/1000
# 11/11 - 0s - loss: 0.0039 - 37ms/epoch - 3ms/step
# Epoch 202/1000
# 11/11 - 0s - loss: 0.0040 - 40ms/epoch - 4ms/step
# Epoch 203/1000
# 11/11 - 0s - loss: 0.0040 - 40ms/epoch - 4ms/step
# Epoch 204/1000
# 11/11 - 0s - loss: 0.0036 - 40ms/epoch - 4ms/step
# Epoch 205/1000
# 11/11 - 0s - loss: 0.0041 - 44ms/epoch - 4ms/step
# Epoch 206/1000
# 11/11 - 0s - loss: 0.0036 - 65ms/epoch - 6ms/step
# Epoch 207/1000
# 11/11 - 0s - loss: 0.0037 - 59ms/epoch - 5ms/step
# Epoch 208/1000
# 11/11 - 0s - loss: 0.0037 - 61ms/epoch - 6ms/step
# Epoch 209/1000
# 11/11 - 0s - loss: 0.0037 - 73ms/epoch - 7ms/step
# Epoch 210/1000
# 11/11 - 0s - loss: 0.0037 - 59ms/epoch - 5ms/step
# Epoch 211/1000
# 11/11 - 0s - loss: 0.0036 - 58ms/epoch - 5ms/step
# Epoch 212/1000
# 11/11 - 0s - loss: 0.0036 - 59ms/epoch - 5ms/step
# Epoch 213/1000
# 11/11 - 0s - loss: 0.0036 - 62ms/epoch - 6ms/step
# Epoch 214/1000
# 11/11 - 0s - loss: 0.0037 - 62ms/epoch - 6ms/step
# Epoch 215/1000
# 11/11 - 0s - loss: 0.0038 - 57ms/epoch - 5ms/step
# Epoch 216/1000
# 11/11 - 0s - loss: 0.0036 - 57ms/epoch - 5ms/step
# Epoch 217/1000
# 11/11 - 0s - loss: 0.0035 - 67ms/epoch - 6ms/step
# Epoch 218/1000
# 11/11 - 0s - loss: 0.0034 - 58ms/epoch - 5ms/step
# Epoch 219/1000
# 11/11 - 0s - loss: 0.0036 - 65ms/epoch - 6ms/step
# Epoch 220/1000
# 11/11 - 0s - loss: 0.0037 - 67ms/epoch - 6ms/step
# Epoch 221/1000
# 11/11 - 0s - loss: 0.0034 - 59ms/epoch - 5ms/step
# Epoch 222/1000
# 11/11 - 0s - loss: 0.0035 - 61ms/epoch - 6ms/step
# Epoch 223/1000
# 11/11 - 0s - loss: 0.0036 - 60ms/epoch - 5ms/step
# Epoch 224/1000
# 11/11 - 0s - loss: 0.0034 - 63ms/epoch - 6ms/step
# Epoch 225/1000
# 11/11 - 0s - loss: 0.0034 - 65ms/epoch - 6ms/step
# Epoch 226/1000
# 11/11 - 0s - loss: 0.0034 - 60ms/epoch - 5ms/step
# Epoch 227/1000
# 11/11 - 0s - loss: 0.0035 - 59ms/epoch - 5ms/step
# Epoch 228/1000
# 11/11 - 0s - loss: 0.0034 - 60ms/epoch - 5ms/step
# Epoch 229/1000
# 11/11 - 0s - loss: 0.0033 - 63ms/epoch - 6ms/step
# Epoch 230/1000
# 11/11 - 0s - loss: 0.0033 - 60ms/epoch - 5ms/step
# Epoch 231/1000
# 11/11 - 0s - loss: 0.0034 - 60ms/epoch - 5ms/step
# Epoch 232/1000
# 11/11 - 0s - loss: 0.0033 - 59ms/epoch - 5ms/step
# Epoch 233/1000
# 11/11 - 0s - loss: 0.0033 - 61ms/epoch - 6ms/step
# Epoch 234/1000
# 11/11 - 0s - loss: 0.0033 - 60ms/epoch - 5ms/step
# Epoch 235/1000
# 11/11 - 0s - loss: 0.0034 - 63ms/epoch - 6ms/step
# Epoch 236/1000
# 11/11 - 0s - loss: 0.0033 - 58ms/epoch - 5ms/step
# Epoch 237/1000
# 11/11 - 0s - loss: 0.0034 - 60ms/epoch - 5ms/step
# Epoch 238/1000
# 11/11 - 0s - loss: 0.0033 - 62ms/epoch - 6ms/step
# Epoch 239/1000
# 11/11 - 0s - loss: 0.0033 - 59ms/epoch - 5ms/step
# Epoch 240/1000
# 11/11 - 0s - loss: 0.0032 - 64ms/epoch - 6ms/step
# Epoch 241/1000
# 11/11 - 0s - loss: 0.0034 - 69ms/epoch - 6ms/step
# Epoch 242/1000
# 11/11 - 0s - loss: 0.0033 - 57ms/epoch - 5ms/step
# Epoch 243/1000
# 11/11 - 0s - loss: 0.0033 - 42ms/epoch - 4ms/step
# Epoch 244/1000
# 11/11 - 0s - loss: 0.0033 - 40ms/epoch - 4ms/step
# Epoch 245/1000
# 11/11 - 0s - loss: 0.0032 - 47ms/epoch - 4ms/step
# Epoch 246/1000
# 11/11 - 0s - loss: 0.0032 - 45ms/epoch - 4ms/step
# Epoch 247/1000
# 11/11 - 0s - loss: 0.0031 - 39ms/epoch - 4ms/step
# Epoch 248/1000
# 11/11 - 0s - loss: 0.0033 - 40ms/epoch - 4ms/step
# Epoch 249/1000
# 11/11 - 0s - loss: 0.0032 - 39ms/epoch - 4ms/step
# Epoch 250/1000
# 11/11 - 0s - loss: 0.0031 - 47ms/epoch - 4ms/step
# Epoch 251/1000
# 11/11 - 0s - loss: 0.0031 - 55ms/epoch - 5ms/step
# Epoch 252/1000
# 11/11 - 0s - loss: 0.0031 - 39ms/epoch - 4ms/step
# Epoch 253/1000
# 11/11 - 0s - loss: 0.0031 - 40ms/epoch - 4ms/step
# Epoch 254/1000
# 11/11 - 0s - loss: 0.0031 - 37ms/epoch - 3ms/step
# Epoch 255/1000
# 11/11 - 0s - loss: 0.0032 - 38ms/epoch - 3ms/step
# Epoch 256/1000
# 11/11 - 0s - loss: 0.0033 - 38ms/epoch - 3ms/step
# Epoch 257/1000
# 11/11 - 0s - loss: 0.0031 - 38ms/epoch - 3ms/step
# Epoch 258/1000
# 11/11 - 0s - loss: 0.0031 - 39ms/epoch - 4ms/step
# Epoch 259/1000
# 11/11 - 0s - loss: 0.0030 - 38ms/epoch - 3ms/step
# Epoch 260/1000
# 11/11 - 0s - loss: 0.0030 - 39ms/epoch - 4ms/step
# Epoch 261/1000
# 11/11 - 0s - loss: 0.0030 - 45ms/epoch - 4ms/step
# Epoch 262/1000
# 11/11 - 0s - loss: 0.0030 - 38ms/epoch - 3ms/step
# Epoch 263/1000
# 11/11 - 0s - loss: 0.0030 - 46ms/epoch - 4ms/step
# Epoch 264/1000
# 11/11 - 0s - loss: 0.0030 - 37ms/epoch - 3ms/step
# Epoch 265/1000
# 11/11 - 0s - loss: 0.0029 - 38ms/epoch - 3ms/step
# Epoch 266/1000
# 11/11 - 0s - loss: 0.0030 - 39ms/epoch - 4ms/step
# Epoch 267/1000
# 11/11 - 0s - loss: 0.0030 - 38ms/epoch - 3ms/step
# Epoch 268/1000
# 11/11 - 0s - loss: 0.0031 - 44ms/epoch - 4ms/step
# Epoch 269/1000
# 11/11 - 0s - loss: 0.0031 - 37ms/epoch - 3ms/step
# Epoch 270/1000
# 11/11 - 0s - loss: 0.0029 - 38ms/epoch - 3ms/step
# Epoch 271/1000
# 11/11 - 0s - loss: 0.0030 - 37ms/epoch - 3ms/step
# Epoch 272/1000
# 11/11 - 0s - loss: 0.0029 - 38ms/epoch - 3ms/step
# Epoch 273/1000
# 11/11 - 0s - loss: 0.0029 - 44ms/epoch - 4ms/step
# Epoch 274/1000
# 11/11 - 0s - loss: 0.0029 - 39ms/epoch - 4ms/step
# Epoch 275/1000
# 11/11 - 0s - loss: 0.0029 - 39ms/epoch - 4ms/step
# Epoch 276/1000
# 11/11 - 0s - loss: 0.0029 - 41ms/epoch - 4ms/step
# Epoch 277/1000
# 11/11 - 0s - loss: 0.0029 - 38ms/epoch - 3ms/step
# Epoch 278/1000
# 11/11 - 0s - loss: 0.0028 - 36ms/epoch - 3ms/step
# Epoch 279/1000
# 11/11 - 0s - loss: 0.0029 - 37ms/epoch - 3ms/step
# Epoch 280/1000
# 11/11 - 0s - loss: 0.0028 - 45ms/epoch - 4ms/step
# Epoch 281/1000
# 11/11 - 0s - loss: 0.0028 - 40ms/epoch - 4ms/step
# Epoch 282/1000
# 11/11 - 0s - loss: 0.0029 - 37ms/epoch - 3ms/step
# Epoch 283/1000
# 11/11 - 0s - loss: 0.0030 - 39ms/epoch - 4ms/step
# Epoch 284/1000
# 11/11 - 0s - loss: 0.0030 - 39ms/epoch - 4ms/step
# Epoch 285/1000
# 11/11 - 0s - loss: 0.0028 - 40ms/epoch - 4ms/step
# Epoch 286/1000
# 11/11 - 0s - loss: 0.0029 - 37ms/epoch - 3ms/step
# Epoch 287/1000
# 11/11 - 0s - loss: 0.0028 - 47ms/epoch - 4ms/step
# Epoch 288/1000
# 11/11 - 0s - loss: 0.0028 - 38ms/epoch - 3ms/step
# Epoch 289/1000
# 11/11 - 0s - loss: 0.0030 - 37ms/epoch - 3ms/step
# Epoch 290/1000
# 11/11 - 0s - loss: 0.0029 - 37ms/epoch - 3ms/step
# Epoch 291/1000
# 11/11 - 0s - loss: 0.0027 - 39ms/epoch - 4ms/step
# Epoch 292/1000
# 11/11 - 0s - loss: 0.0028 - 38ms/epoch - 3ms/step
# Epoch 293/1000
# 11/11 - 0s - loss: 0.0027 - 36ms/epoch - 3ms/step
# Epoch 294/1000
# 11/11 - 0s - loss: 0.0027 - 36ms/epoch - 3ms/step
# Epoch 295/1000
# 11/11 - 0s - loss: 0.0028 - 36ms/epoch - 3ms/step
# Epoch 296/1000
# 11/11 - 0s - loss: 0.0028 - 45ms/epoch - 4ms/step
# Epoch 297/1000
# 11/11 - 0s - loss: 0.0027 - 38ms/epoch - 3ms/step
# Epoch 298/1000
# 11/11 - 0s - loss: 0.0027 - 38ms/epoch - 3ms/step
# Epoch 299/1000
# 11/11 - 0s - loss: 0.0030 - 40ms/epoch - 4ms/step
# Epoch 300/1000
# 11/11 - 0s - loss: 0.0027 - 41ms/epoch - 4ms/step
# Epoch 301/1000
# 11/11 - 0s - loss: 0.0027 - 38ms/epoch - 3ms/step
# Epoch 302/1000
# 11/11 - 0s - loss: 0.0026 - 38ms/epoch - 3ms/step
# Epoch 303/1000
# 11/11 - 0s - loss: 0.0026 - 39ms/epoch - 4ms/step
# Epoch 304/1000
# 11/11 - 0s - loss: 0.0026 - 43ms/epoch - 4ms/step
# Epoch 305/1000
# 11/11 - 0s - loss: 0.0026 - 38ms/epoch - 3ms/step
# Epoch 306/1000
# 11/11 - 0s - loss: 0.0026 - 38ms/epoch - 3ms/step
# Epoch 307/1000
# 11/11 - 0s - loss: 0.0026 - 37ms/epoch - 3ms/step
# Epoch 308/1000
# 11/11 - 0s - loss: 0.0026 - 39ms/epoch - 4ms/step
# Epoch 309/1000
# 11/11 - 0s - loss: 0.0026 - 37ms/epoch - 3ms/step
# Epoch 310/1000
# 11/11 - 0s - loss: 0.0026 - 38ms/epoch - 3ms/step
# Epoch 311/1000
# 11/11 - 0s - loss: 0.0026 - 52ms/epoch - 5ms/step
# Epoch 312/1000
# 11/11 - 0s - loss: 0.0026 - 38ms/epoch - 3ms/step
# Epoch 313/1000
# 11/11 - 0s - loss: 0.0026 - 38ms/epoch - 3ms/step
# Epoch 314/1000
# 11/11 - 0s - loss: 0.0026 - 38ms/epoch - 3ms/step
# Epoch 315/1000
# 11/11 - 0s - loss: 0.0026 - 39ms/epoch - 4ms/step
# Epoch 316/1000
# 11/11 - 0s - loss: 0.0026 - 37ms/epoch - 3ms/step
# Epoch 317/1000
# 11/11 - 0s - loss: 0.0025 - 38ms/epoch - 3ms/step
# Epoch 318/1000
# 11/11 - 0s - loss: 0.0025 - 42ms/epoch - 4ms/step
# Epoch 319/1000
# 11/11 - 0s - loss: 0.0025 - 40ms/epoch - 4ms/step
# Epoch 320/1000
# 11/11 - 0s - loss: 0.0025 - 40ms/epoch - 4ms/step
# Epoch 321/1000
# 11/11 - 0s - loss: 0.0025 - 39ms/epoch - 4ms/step
# Epoch 322/1000
# 11/11 - 0s - loss: 0.0025 - 39ms/epoch - 4ms/step
# Epoch 323/1000
# 11/11 - 0s - loss: 0.0025 - 45ms/epoch - 4ms/step
# Epoch 324/1000
# 11/11 - 0s - loss: 0.0025 - 37ms/epoch - 3ms/step
# Epoch 325/1000
# 11/11 - 0s - loss: 0.0025 - 38ms/epoch - 3ms/step
# Epoch 326/1000
# 11/11 - 0s - loss: 0.0025 - 40ms/epoch - 4ms/step
# Epoch 327/1000
# 11/11 - 0s - loss: 0.0025 - 39ms/epoch - 4ms/step
# Epoch 328/1000
# 11/11 - 0s - loss: 0.0025 - 41ms/epoch - 4ms/step
# Epoch 329/1000
# 11/11 - 0s - loss: 0.0024 - 37ms/epoch - 3ms/step
# Epoch 330/1000
# 11/11 - 0s - loss: 0.0024 - 46ms/epoch - 4ms/step
# Epoch 331/1000
# 11/11 - 0s - loss: 0.0024 - 40ms/epoch - 4ms/step
# Epoch 332/1000
# 11/11 - 0s - loss: 0.0024 - 41ms/epoch - 4ms/step
# Epoch 333/1000
# 11/11 - 0s - loss: 0.0024 - 38ms/epoch - 3ms/step
# Epoch 334/1000
# 11/11 - 0s - loss: 0.0025 - 41ms/epoch - 4ms/step
# Epoch 335/1000
# 11/11 - 0s - loss: 0.0027 - 43ms/epoch - 4ms/step
# Epoch 336/1000
# 11/11 - 0s - loss: 0.0024 - 38ms/epoch - 3ms/step
# Epoch 337/1000
# 11/11 - 0s - loss: 0.0024 - 45ms/epoch - 4ms/step
# Epoch 338/1000
# 11/11 - 0s - loss: 0.0024 - 39ms/epoch - 4ms/step
# Epoch 339/1000
# 11/11 - 0s - loss: 0.0025 - 38ms/epoch - 3ms/step
# Epoch 340/1000
# 11/11 - 0s - loss: 0.0024 - 40ms/epoch - 4ms/step
# Epoch 341/1000
# 11/11 - 0s - loss: 0.0026 - 37ms/epoch - 3ms/step
# Epoch 342/1000
# 11/11 - 0s - loss: 0.0023 - 38ms/epoch - 3ms/step
# Epoch 343/1000
# 11/11 - 0s - loss: 0.0024 - 37ms/epoch - 3ms/step
# Epoch 344/1000
# 11/11 - 0s - loss: 0.0023 - 37ms/epoch - 3ms/step
# Epoch 345/1000
# 11/11 - 0s - loss: 0.0024 - 39ms/epoch - 4ms/step
# Epoch 346/1000
# 11/11 - 0s - loss: 0.0024 - 45ms/epoch - 4ms/step
# Epoch 347/1000
# 11/11 - 0s - loss: 0.0024 - 45ms/epoch - 4ms/step
# Epoch 348/1000
# 11/11 - 0s - loss: 0.0025 - 43ms/epoch - 4ms/step
# Epoch 349/1000
# 11/11 - 0s - loss: 0.0024 - 39ms/epoch - 4ms/step
# Epoch 350/1000
# 11/11 - 0s - loss: 0.0028 - 40ms/epoch - 4ms/step
# Epoch 351/1000
# 11/11 - 0s - loss: 0.0023 - 39ms/epoch - 4ms/step
# Epoch 352/1000
# 11/11 - 0s - loss: 0.0022 - 37ms/epoch - 3ms/step
# Epoch 353/1000
# 11/11 - 0s - loss: 0.0024 - 37ms/epoch - 3ms/step
# Epoch 354/1000
# 11/11 - 0s - loss: 0.0024 - 39ms/epoch - 4ms/step
# Epoch 355/1000
# 11/11 - 0s - loss: 0.0023 - 37ms/epoch - 3ms/step
# Epoch 356/1000
# 11/11 - 0s - loss: 0.0023 - 43ms/epoch - 4ms/step
# Epoch 357/1000
# 11/11 - 0s - loss: 0.0023 - 37ms/epoch - 3ms/step
# Epoch 358/1000
# 11/11 - 0s - loss: 0.0023 - 47ms/epoch - 4ms/step
# Epoch 359/1000
# 11/11 - 0s - loss: 0.0022 - 39ms/epoch - 4ms/step
# Epoch 360/1000
# 11/11 - 0s - loss: 0.0023 - 39ms/epoch - 4ms/step
# Epoch 361/1000
# 11/11 - 0s - loss: 0.0023 - 45ms/epoch - 4ms/step
# Epoch 362/1000
# 11/11 - 0s - loss: 0.0023 - 38ms/epoch - 3ms/step
# Epoch 363/1000
# 11/11 - 0s - loss: 0.0023 - 39ms/epoch - 4ms/step
# Epoch 364/1000
# 11/11 - 0s - loss: 0.0023 - 38ms/epoch - 3ms/step
# Epoch 365/1000
# 11/11 - 0s - loss: 0.0024 - 37ms/epoch - 3ms/step
# Epoch 366/1000
# 11/11 - 0s - loss: 0.0024 - 44ms/epoch - 4ms/step
# Epoch 367/1000
# 11/11 - 0s - loss: 0.0022 - 36ms/epoch - 3ms/step
# Epoch 368/1000
# 11/11 - 0s - loss: 0.0025 - 38ms/epoch - 3ms/step
# Epoch 369/1000
# 11/11 - 0s - loss: 0.0023 - 38ms/epoch - 3ms/step
# Epoch 370/1000
# 11/11 - 0s - loss: 0.0022 - 41ms/epoch - 4ms/step
# Epoch 371/1000
# 11/11 - 0s - loss: 0.0024 - 38ms/epoch - 3ms/step
# Epoch 372/1000
# 11/11 - 0s - loss: 0.0024 - 36ms/epoch - 3ms/step
# Epoch 373/1000
# 11/11 - 0s - loss: 0.0021 - 39ms/epoch - 4ms/step
# Epoch 374/1000
# 11/11 - 0s - loss: 0.0022 - 37ms/epoch - 3ms/step
# Epoch 375/1000
# 11/11 - 0s - loss: 0.0021 - 38ms/epoch - 3ms/step
# Epoch 376/1000
# 11/11 - 0s - loss: 0.0022 - 39ms/epoch - 4ms/step
# Epoch 377/1000
# 11/11 - 0s - loss: 0.0022 - 39ms/epoch - 4ms/step
# Epoch 378/1000
# 11/11 - 0s - loss: 0.0026 - 44ms/epoch - 4ms/step
# Epoch 379/1000
# 11/11 - 0s - loss: 0.0026 - 37ms/epoch - 3ms/step
# Epoch 380/1000
# 11/11 - 0s - loss: 0.0024 - 36ms/epoch - 3ms/step
# Epoch 381/1000
# 11/11 - 0s - loss: 0.0026 - 38ms/epoch - 3ms/step
# Epoch 382/1000
# 11/11 - 0s - loss: 0.0021 - 44ms/epoch - 4ms/step
# Epoch 383/1000
# 11/11 - 0s - loss: 0.0022 - 48ms/epoch - 4ms/step
# Epoch 384/1000
# 11/11 - 0s - loss: 0.0021 - 42ms/epoch - 4ms/step
# Epoch 385/1000
# 11/11 - 0s - loss: 0.0021 - 39ms/epoch - 4ms/step
# Epoch 386/1000
# 11/11 - 0s - loss: 0.0023 - 37ms/epoch - 3ms/step
# Epoch 387/1000
# 11/11 - 0s - loss: 0.0021 - 38ms/epoch - 3ms/step
# Epoch 388/1000
# 11/11 - 0s - loss: 0.0021 - 40ms/epoch - 4ms/step
# Epoch 389/1000
# 11/11 - 0s - loss: 0.0023 - 41ms/epoch - 4ms/step
# Epoch 390/1000
# 11/11 - 0s - loss: 0.0021 - 46ms/epoch - 4ms/step
# Epoch 391/1000
# 11/11 - 0s - loss: 0.0021 - 38ms/epoch - 3ms/step
# Epoch 392/1000
# 11/11 - 0s - loss: 0.0021 - 38ms/epoch - 3ms/step
# Epoch 393/1000
# 11/11 - 0s - loss: 0.0020 - 38ms/epoch - 3ms/step
# Epoch 394/1000
# 11/11 - 0s - loss: 0.0021 - 41ms/epoch - 4ms/step
# Epoch 395/1000
# 11/11 - 0s - loss: 0.0022 - 41ms/epoch - 4ms/step
# Epoch 396/1000
# 11/11 - 0s - loss: 0.0023 - 39ms/epoch - 4ms/step
# Epoch 397/1000
# 11/11 - 0s - loss: 0.0021 - 40ms/epoch - 4ms/step
# Epoch 398/1000
# 11/11 - 0s - loss: 0.0021 - 39ms/epoch - 4ms/step
# Epoch 399/1000
# 11/11 - 0s - loss: 0.0020 - 38ms/epoch - 3ms/step
# Epoch 400/1000
# 11/11 - 0s - loss: 0.0020 - 47ms/epoch - 4ms/step
# Epoch 401/1000
# 11/11 - 0s - loss: 0.0022 - 41ms/epoch - 4ms/step
# Epoch 402/1000
# 11/11 - 0s - loss: 0.0022 - 41ms/epoch - 4ms/step
# Epoch 403/1000
# 11/11 - 0s - loss: 0.0021 - 38ms/epoch - 3ms/step
# Epoch 404/1000
# 11/11 - 0s - loss: 0.0021 - 38ms/epoch - 3ms/step
# Epoch 405/1000
# 11/11 - 0s - loss: 0.0022 - 46ms/epoch - 4ms/step
# Epoch 406/1000
# 11/11 - 0s - loss: 0.0020 - 48ms/epoch - 4ms/step
# Epoch 407/1000
# 11/11 - 0s - loss: 0.0020 - 47ms/epoch - 4ms/step
# Epoch 408/1000
# 11/11 - 0s - loss: 0.0020 - 40ms/epoch - 4ms/step
# Epoch 409/1000
# 11/11 - 0s - loss: 0.0023 - 39ms/epoch - 4ms/step
# Epoch 410/1000
# 11/11 - 0s - loss: 0.0020 - 39ms/epoch - 4ms/step
# Epoch 411/1000
# 11/11 - 0s - loss: 0.0021 - 37ms/epoch - 3ms/step
# Epoch 412/1000
# 11/11 - 0s - loss: 0.0021 - 38ms/epoch - 3ms/step
# Epoch 413/1000
# 11/11 - 0s - loss: 0.0024 - 45ms/epoch - 4ms/step
# Epoch 414/1000
# 11/11 - 0s - loss: 0.0019 - 40ms/epoch - 4ms/step
# Epoch 415/1000
# 11/11 - 0s - loss: 0.0023 - 38ms/epoch - 3ms/step
# Epoch 416/1000
# 11/11 - 0s - loss: 0.0020 - 39ms/epoch - 4ms/step
# Epoch 417/1000
# 11/11 - 0s - loss: 0.0020 - 42ms/epoch - 4ms/step
# Epoch 418/1000
# 11/11 - 0s - loss: 0.0020 - 42ms/epoch - 4ms/step
# Epoch 419/1000
# 11/11 - 0s - loss: 0.0020 - 38ms/epoch - 3ms/step
# Epoch 420/1000
# 11/11 - 0s - loss: 0.0019 - 38ms/epoch - 3ms/step
# Epoch 421/1000
# 11/11 - 0s - loss: 0.0019 - 46ms/epoch - 4ms/step
# Epoch 422/1000
# 11/11 - 0s - loss: 0.0020 - 39ms/epoch - 4ms/step
# Epoch 423/1000
# 11/11 - 0s - loss: 0.0020 - 39ms/epoch - 4ms/step
# Epoch 424/1000
# 11/11 - 0s - loss: 0.0019 - 39ms/epoch - 4ms/step
# Epoch 425/1000
# 11/11 - 0s - loss: 0.0020 - 39ms/epoch - 4ms/step
# Epoch 426/1000
# 11/11 - 0s - loss: 0.0020 - 39ms/epoch - 4ms/step
# Epoch 427/1000
# 11/11 - 0s - loss: 0.0020 - 40ms/epoch - 4ms/step
# Epoch 428/1000
# 11/11 - 0s - loss: 0.0019 - 47ms/epoch - 4ms/step
# Epoch 429/1000
# 11/11 - 0s - loss: 0.0022 - 47ms/epoch - 4ms/step
# Epoch 430/1000
# 11/11 - 0s - loss: 0.0020 - 41ms/epoch - 4ms/step
# Epoch 431/1000
# 11/11 - 0s - loss: 0.0019 - 38ms/epoch - 3ms/step
# Epoch 432/1000
# 11/11 - 0s - loss: 0.0021 - 38ms/epoch - 3ms/step
# Epoch 433/1000
# 11/11 - 0s - loss: 0.0020 - 40ms/epoch - 4ms/step
# Epoch 434/1000
# 11/11 - 0s - loss: 0.0018 - 46ms/epoch - 4ms/step
# Epoch 435/1000
# 11/11 - 0s - loss: 0.0020 - 38ms/epoch - 3ms/step
# Epoch 436/1000
# 11/11 - 0s - loss: 0.0019 - 40ms/epoch - 4ms/step
# Epoch 437/1000
# 11/11 - 0s - loss: 0.0018 - 40ms/epoch - 4ms/step
# Epoch 438/1000
# 11/11 - 0s - loss: 0.0018 - 38ms/epoch - 3ms/step
# Epoch 439/1000
# 11/11 - 0s - loss: 0.0018 - 43ms/epoch - 4ms/step
# Epoch 440/1000
# 11/11 - 0s - loss: 0.0018 - 41ms/epoch - 4ms/step
# Epoch 441/1000
# 11/11 - 0s - loss: 0.0019 - 38ms/epoch - 3ms/step
# Epoch 442/1000
# 11/11 - 0s - loss: 0.0020 - 39ms/epoch - 4ms/step
# Epoch 443/1000
# 11/11 - 0s - loss: 0.0019 - 39ms/epoch - 4ms/step
# Epoch 444/1000
# 11/11 - 0s - loss: 0.0018 - 40ms/epoch - 4ms/step
# Epoch 445/1000
# 11/11 - 0s - loss: 0.0019 - 37ms/epoch - 3ms/step
# Epoch 446/1000
# 11/11 - 0s - loss: 0.0020 - 37ms/epoch - 3ms/step
# Epoch 447/1000
# 11/11 - 0s - loss: 0.0018 - 40ms/epoch - 4ms/step
# Epoch 448/1000
# 11/11 - 0s - loss: 0.0019 - 39ms/epoch - 4ms/step
# Epoch 449/1000
# 11/11 - 0s - loss: 0.0019 - 45ms/epoch - 4ms/step
# Epoch 450/1000
# 11/11 - 0s - loss: 0.0019 - 38ms/epoch - 3ms/step
# Epoch 451/1000
# 11/11 - 0s - loss: 0.0019 - 38ms/epoch - 3ms/step
# Epoch 452/1000
# 11/11 - 0s - loss: 0.0019 - 45ms/epoch - 4ms/step
# Epoch 453/1000
# 11/11 - 0s - loss: 0.0018 - 41ms/epoch - 4ms/step
# Epoch 454/1000
# 11/11 - 0s - loss: 0.0018 - 38ms/epoch - 3ms/step
# Epoch 455/1000
# 11/11 - 0s - loss: 0.0018 - 40ms/epoch - 4ms/step
# Epoch 456/1000
# 11/11 - 0s - loss: 0.0019 - 37ms/epoch - 3ms/step
# Epoch 457/1000
# 11/11 - 0s - loss: 0.0018 - 40ms/epoch - 4ms/step
# Epoch 458/1000
# 11/11 - 0s - loss: 0.0018 - 40ms/epoch - 4ms/step
# Epoch 459/1000
# 11/11 - 0s - loss: 0.0018 - 38ms/epoch - 3ms/step
# Epoch 460/1000
# 11/11 - 0s - loss: 0.0018 - 38ms/epoch - 3ms/step
# Epoch 461/1000
# 11/11 - 0s - loss: 0.0018 - 38ms/epoch - 3ms/step
# Epoch 462/1000
# 11/11 - 0s - loss: 0.0018 - 41ms/epoch - 4ms/step
# Epoch 463/1000
# 11/11 - 0s - loss: 0.0018 - 48ms/epoch - 4ms/step
# Epoch 464/1000
# 11/11 - 0s - loss: 0.0018 - 38ms/epoch - 3ms/step
# Epoch 465/1000
# 11/11 - 0s - loss: 0.0018 - 37ms/epoch - 3ms/step
# Epoch 466/1000
# 11/11 - 0s - loss: 0.0020 - 37ms/epoch - 3ms/step
# Epoch 467/1000
# 11/11 - 0s - loss: 0.0017 - 38ms/epoch - 3ms/step
# Epoch 468/1000
# 11/11 - 0s - loss: 0.0019 - 46ms/epoch - 4ms/step
# Epoch 469/1000
# 11/11 - 0s - loss: 0.0018 - 48ms/epoch - 4ms/step
# Epoch 470/1000
# 11/11 - 0s - loss: 0.0017 - 39ms/epoch - 4ms/step
# Epoch 471/1000
# 11/11 - 0s - loss: 0.0018 - 41ms/epoch - 4ms/step
# Epoch 472/1000
# 11/11 - 0s - loss: 0.0017 - 40ms/epoch - 4ms/step
# Epoch 473/1000
# 11/11 - 0s - loss: 0.0017 - 39ms/epoch - 4ms/step
# Epoch 474/1000
# 11/11 - 0s - loss: 0.0017 - 60ms/epoch - 5ms/step
# Epoch 475/1000
# 11/11 - 0s - loss: 0.0018 - 63ms/epoch - 6ms/step
# Epoch 476/1000
# 11/11 - 0s - loss: 0.0021 - 65ms/epoch - 6ms/step
# Epoch 477/1000
# 11/11 - 0s - loss: 0.0017 - 60ms/epoch - 5ms/step
# Epoch 478/1000
# 11/11 - 0s - loss: 0.0018 - 63ms/epoch - 6ms/step
# Epoch 479/1000
# 11/11 - 0s - loss: 0.0017 - 62ms/epoch - 6ms/step
# Epoch 480/1000
# 11/11 - 0s - loss: 0.0018 - 64ms/epoch - 6ms/step
# Epoch 481/1000
# 11/11 - 0s - loss: 0.0018 - 62ms/epoch - 6ms/step
# Epoch 482/1000
# 11/11 - 0s - loss: 0.0018 - 69ms/epoch - 6ms/step
# Epoch 483/1000
# 11/11 - 0s - loss: 0.0019 - 58ms/epoch - 5ms/step
# Epoch 484/1000
# 11/11 - 0s - loss: 0.0017 - 57ms/epoch - 5ms/step
# Epoch 485/1000
# 11/11 - 0s - loss: 0.0017 - 60ms/epoch - 5ms/step
# Epoch 486/1000
# 11/11 - 0s - loss: 0.0017 - 63ms/epoch - 6ms/step
# Epoch 487/1000
# 11/11 - 0s - loss: 0.0017 - 62ms/epoch - 6ms/step
# Epoch 488/1000
# 11/11 - 0s - loss: 0.0017 - 63ms/epoch - 6ms/step
# Epoch 489/1000
# 11/11 - 0s - loss: 0.0017 - 62ms/epoch - 6ms/step
# Epoch 490/1000
# 11/11 - 0s - loss: 0.0017 - 59ms/epoch - 5ms/step
# Epoch 491/1000
# 11/11 - 0s - loss: 0.0017 - 66ms/epoch - 6ms/step
# Epoch 492/1000
# 11/11 - 0s - loss: 0.0017 - 60ms/epoch - 5ms/step
# Epoch 493/1000
# 11/11 - 0s - loss: 0.0017 - 61ms/epoch - 6ms/step
# Epoch 494/1000
# 11/11 - 0s - loss: 0.0017 - 60ms/epoch - 5ms/step
# Epoch 495/1000
# 11/11 - 0s - loss: 0.0019 - 58ms/epoch - 5ms/step
# Epoch 496/1000
# 11/11 - 0s - loss: 0.0017 - 63ms/epoch - 6ms/step
# Epoch 497/1000
# 11/11 - 0s - loss: 0.0017 - 58ms/epoch - 5ms/step
# Epoch 498/1000
# 11/11 - 0s - loss: 0.0016 - 59ms/epoch - 5ms/step
# Epoch 499/1000
# 11/11 - 0s - loss: 0.0019 - 58ms/epoch - 5ms/step
# Epoch 500/1000
# 11/11 - 0s - loss: 0.0016 - 60ms/epoch - 5ms/step
# Epoch 501/1000
# 11/11 - 0s - loss: 0.0017 - 60ms/epoch - 5ms/step
# Epoch 502/1000
# 11/11 - 0s - loss: 0.0017 - 59ms/epoch - 5ms/step
# Epoch 503/1000
# 11/11 - 0s - loss: 0.0017 - 62ms/epoch - 6ms/step
# Epoch 504/1000
# 11/11 - 0s - loss: 0.0017 - 60ms/epoch - 5ms/step
# Epoch 505/1000
# 11/11 - 0s - loss: 0.0016 - 62ms/epoch - 6ms/step
# Epoch 506/1000
# 11/11 - 0s - loss: 0.0016 - 63ms/epoch - 6ms/step
# Epoch 507/1000
# 11/11 - 0s - loss: 0.0017 - 73ms/epoch - 7ms/step
# Epoch 508/1000
# 11/11 - 0s - loss: 0.0016 - 66ms/epoch - 6ms/step
# Epoch 509/1000
# 11/11 - 0s - loss: 0.0017 - 70ms/epoch - 6ms/step
# Epoch 510/1000
# 11/11 - 0s - loss: 0.0021 - 60ms/epoch - 5ms/step
# Epoch 511/1000
# 11/11 - 0s - loss: 0.0019 - 58ms/epoch - 5ms/step
# Epoch 512/1000
# 11/11 - 0s - loss: 0.0016 - 60ms/epoch - 5ms/step
# Epoch 513/1000
# 11/11 - 0s - loss: 0.0017 - 66ms/epoch - 6ms/step
# Epoch 514/1000
# 11/11 - 0s - loss: 0.0016 - 54ms/epoch - 5ms/step
# Epoch 515/1000
# 11/11 - 0s - loss: 0.0016 - 40ms/epoch - 4ms/step
# Epoch 516/1000
# 11/11 - 0s - loss: 0.0016 - 38ms/epoch - 3ms/step
# Epoch 517/1000
# 11/11 - 0s - loss: 0.0020 - 39ms/epoch - 4ms/step
# Epoch 518/1000
# 11/11 - 0s - loss: 0.0016 - 38ms/epoch - 3ms/step
# Epoch 519/1000
# 11/11 - 0s - loss: 0.0016 - 47ms/epoch - 4ms/step
# Epoch 520/1000
# 11/11 - 0s - loss: 0.0016 - 38ms/epoch - 3ms/step
# Epoch 521/1000
# 11/11 - 0s - loss: 0.0016 - 39ms/epoch - 4ms/step
# Epoch 522/1000
# 11/11 - 0s - loss: 0.0018 - 47ms/epoch - 4ms/step
# Epoch 523/1000
# 11/11 - 0s - loss: 0.0016 - 41ms/epoch - 4ms/step
# Epoch 524/1000
# 11/11 - 0s - loss: 0.0017 - 41ms/epoch - 4ms/step
# Epoch 525/1000
# 11/11 - 0s - loss: 0.0017 - 40ms/epoch - 4ms/step
# Epoch 526/1000
# 11/11 - 0s - loss: 0.0017 - 38ms/epoch - 3ms/step
# Epoch 527/1000
# 11/11 - 0s - loss: 0.0016 - 39ms/epoch - 4ms/step
# Epoch 528/1000
# 11/11 - 0s - loss: 0.0016 - 55ms/epoch - 5ms/step
# Epoch 529/1000
# 11/11 - 0s - loss: 0.0017 - 40ms/epoch - 4ms/step
# Epoch 530/1000
# 11/11 - 0s - loss: 0.0016 - 37ms/epoch - 3ms/step
# Epoch 531/1000
# 11/11 - 0s - loss: 0.0016 - 37ms/epoch - 3ms/step
# Epoch 532/1000
# 11/11 - 0s - loss: 0.0017 - 44ms/epoch - 4ms/step
# Epoch 533/1000
# 11/11 - 0s - loss: 0.0016 - 42ms/epoch - 4ms/step
# Epoch 534/1000
# 11/11 - 0s - loss: 0.0017 - 40ms/epoch - 4ms/step
# Epoch 535/1000
# 11/11 - 0s - loss: 0.0017 - 39ms/epoch - 4ms/step
# Epoch 536/1000
# 11/11 - 0s - loss: 0.0019 - 39ms/epoch - 4ms/step
# Epoch 537/1000
# 11/11 - 0s - loss: 0.0016 - 40ms/epoch - 4ms/step
# Epoch 538/1000
# 11/11 - 0s - loss: 0.0016 - 39ms/epoch - 4ms/step
# Epoch 539/1000
# 11/11 - 0s - loss: 0.0016 - 49ms/epoch - 4ms/step
# Epoch 540/1000
# 11/11 - 0s - loss: 0.0016 - 39ms/epoch - 4ms/step
# Epoch 541/1000
# 11/11 - 0s - loss: 0.0015 - 38ms/epoch - 3ms/step
# Epoch 542/1000
# 11/11 - 0s - loss: 0.0018 - 40ms/epoch - 4ms/step
# Epoch 543/1000
# 11/11 - 0s - loss: 0.0015 - 46ms/epoch - 4ms/step
# Epoch 544/1000
# 11/11 - 0s - loss: 0.0016 - 38ms/epoch - 3ms/step
# Epoch 545/1000
# 11/11 - 0s - loss: 0.0015 - 37ms/epoch - 3ms/step
# Epoch 546/1000
# 11/11 - 0s - loss: 0.0015 - 40ms/epoch - 4ms/step
# Epoch 547/1000
# 11/11 - 0s - loss: 0.0015 - 46ms/epoch - 4ms/step
# Epoch 548/1000
# 11/11 - 0s - loss: 0.0015 - 40ms/epoch - 4ms/step
# Epoch 549/1000
# 11/11 - 0s - loss: 0.0015 - 38ms/epoch - 3ms/step
# Epoch 550/1000
# 11/11 - 0s - loss: 0.0015 - 41ms/epoch - 4ms/step
# Epoch 551/1000
# 11/11 - 0s - loss: 0.0015 - 47ms/epoch - 4ms/step
# Epoch 552/1000
# 11/11 - 0s - loss: 0.0015 - 44ms/epoch - 4ms/step
# Epoch 553/1000
# 11/11 - 0s - loss: 0.0016 - 38ms/epoch - 3ms/step
# Epoch 554/1000
# 11/11 - 0s - loss: 0.0015 - 37ms/epoch - 3ms/step
# Epoch 555/1000
# 11/11 - 0s - loss: 0.0015 - 39ms/epoch - 4ms/step
# Epoch 556/1000
# 11/11 - 0s - loss: 0.0016 - 38ms/epoch - 3ms/step
# Epoch 557/1000
# 11/11 - 0s - loss: 0.0015 - 44ms/epoch - 4ms/step
# Epoch 558/1000
# 11/11 - 0s - loss: 0.0017 - 40ms/epoch - 4ms/step
# Epoch 559/1000
# 11/11 - 0s - loss: 0.0019 - 38ms/epoch - 3ms/step
# Epoch 560/1000
# 11/11 - 0s - loss: 0.0017 - 38ms/epoch - 3ms/step
# Epoch 561/1000
# 11/11 - 0s - loss: 0.0020 - 42ms/epoch - 4ms/step
# Epoch 562/1000
# 11/11 - 0s - loss: 0.0016 - 39ms/epoch - 4ms/step
# Epoch 563/1000
# 11/11 - 0s - loss: 0.0016 - 39ms/epoch - 4ms/step
# Epoch 564/1000
# 11/11 - 0s - loss: 0.0016 - 48ms/epoch - 4ms/step
# Epoch 565/1000
# 11/11 - 0s - loss: 0.0015 - 39ms/epoch - 4ms/step
# Epoch 566/1000
# 11/11 - 0s - loss: 0.0017 - 38ms/epoch - 3ms/step
# Epoch 567/1000
# 11/11 - 0s - loss: 0.0016 - 37ms/epoch - 3ms/step
# Epoch 568/1000
# 11/11 - 0s - loss: 0.0017 - 38ms/epoch - 3ms/step
# Epoch 569/1000
# 11/11 - 0s - loss: 0.0015 - 38ms/epoch - 3ms/step
# Epoch 570/1000
# 11/11 - 0s - loss: 0.0015 - 40ms/epoch - 4ms/step
# Epoch 571/1000
# 11/11 - 0s - loss: 0.0018 - 38ms/epoch - 3ms/step
# Epoch 572/1000
# 11/11 - 0s - loss: 0.0019 - 36ms/epoch - 3ms/step
# Epoch 573/1000
# 11/11 - 0s - loss: 0.0016 - 39ms/epoch - 4ms/step
# Epoch 574/1000
# 11/11 - 0s - loss: 0.0015 - 50ms/epoch - 5ms/step
# Epoch 575/1000
# 11/11 - 0s - loss: 0.0015 - 49ms/epoch - 4ms/step
# Epoch 576/1000
# 11/11 - 0s - loss: 0.0015 - 39ms/epoch - 4ms/step
# Epoch 577/1000
# 11/11 - 0s - loss: 0.0015 - 46ms/epoch - 4ms/step
# Epoch 578/1000
# 11/11 - 0s - loss: 0.0015 - 41ms/epoch - 4ms/step
# Epoch 579/1000
# 11/11 - 0s - loss: 0.0015 - 38ms/epoch - 3ms/step
# Epoch 580/1000
# 11/11 - 0s - loss: 0.0015 - 37ms/epoch - 3ms/step
# Epoch 581/1000
# 11/11 - 0s - loss: 0.0015 - 38ms/epoch - 3ms/step
# Epoch 582/1000
# 11/11 - 0s - loss: 0.0015 - 36ms/epoch - 3ms/step
# Epoch 583/1000
# 11/11 - 0s - loss: 0.0015 - 37ms/epoch - 3ms/step
# Epoch 584/1000
# 11/11 - 0s - loss: 0.0015 - 46ms/epoch - 4ms/step
# Epoch 585/1000
# 11/11 - 0s - loss: 0.0015 - 42ms/epoch - 4ms/step
# Epoch 586/1000
# 11/11 - 0s - loss: 0.0015 - 43ms/epoch - 4ms/step
# Epoch 587/1000
# 11/11 - 0s - loss: 0.0015 - 41ms/epoch - 4ms/step
# Epoch 588/1000
# 11/11 - 0s - loss: 0.0015 - 39ms/epoch - 4ms/step
# Epoch 589/1000
# 11/11 - 0s - loss: 0.0015 - 41ms/epoch - 4ms/step
# Epoch 590/1000
# 11/11 - 0s - loss: 0.0015 - 38ms/epoch - 3ms/step
# Epoch 591/1000
# 11/11 - 0s - loss: 0.0015 - 40ms/epoch - 4ms/step
# Epoch 592/1000
# 11/11 - 0s - loss: 0.0015 - 40ms/epoch - 4ms/step
# Epoch 593/1000
# 11/11 - 0s - loss: 0.0015 - 46ms/epoch - 4ms/step
# Epoch 594/1000
# 11/11 - 0s - loss: 0.0016 - 40ms/epoch - 4ms/step
# Epoch 595/1000
# 11/11 - 0s - loss: 0.0015 - 40ms/epoch - 4ms/step
# Epoch 596/1000
# 11/11 - 0s - loss: 0.0014 - 58ms/epoch - 5ms/step
# Epoch 597/1000
# 11/11 - 0s - loss: 0.0014 - 46ms/epoch - 4ms/step
# Epoch 598/1000
# 11/11 - 0s - loss: 0.0014 - 39ms/epoch - 4ms/step
# Epoch 599/1000
# 11/11 - 0s - loss: 0.0014 - 43ms/epoch - 4ms/step
# Epoch 600/1000
# 11/11 - 0s - loss: 0.0016 - 37ms/epoch - 3ms/step
# Epoch 601/1000
# 11/11 - 0s - loss: 0.0017 - 37ms/epoch - 3ms/step
# Epoch 602/1000
# 11/11 - 0s - loss: 0.0014 - 37ms/epoch - 3ms/step
# Epoch 603/1000
# 11/11 - 0s - loss: 0.0015 - 38ms/epoch - 3ms/step
# Epoch 604/1000
# 11/11 - 0s - loss: 0.0015 - 39ms/epoch - 4ms/step
# Epoch 605/1000
# 11/11 - 0s - loss: 0.0015 - 38ms/epoch - 3ms/step
# Epoch 606/1000
# 11/11 - 0s - loss: 0.0015 - 46ms/epoch - 4ms/step
# Epoch 607/1000
# 11/11 - 0s - loss: 0.0014 - 45ms/epoch - 4ms/step
# Epoch 608/1000
# 11/11 - 0s - loss: 0.0014 - 38ms/epoch - 3ms/step
# Epoch 609/1000
# 11/11 - 0s - loss: 0.0015 - 38ms/epoch - 3ms/step
# Epoch 610/1000
# 11/11 - 0s - loss: 0.0014 - 38ms/epoch - 3ms/step
# Epoch 611/1000
# 11/11 - 0s - loss: 0.0015 - 38ms/epoch - 3ms/step
# Epoch 612/1000
# 11/11 - 0s - loss: 0.0014 - 39ms/epoch - 4ms/step
# Epoch 613/1000
# 11/11 - 0s - loss: 0.0014 - 38ms/epoch - 3ms/step
# Epoch 614/1000
# 11/11 - 0s - loss: 0.0015 - 40ms/epoch - 4ms/step
# Epoch 615/1000
# 11/11 - 0s - loss: 0.0014 - 47ms/epoch - 4ms/step
# Epoch 616/1000
# 11/11 - 0s - loss: 0.0015 - 38ms/epoch - 3ms/step
# Epoch 617/1000
# 11/11 - 0s - loss: 0.0014 - 38ms/epoch - 3ms/step
# Epoch 618/1000
# 11/11 - 0s - loss: 0.0014 - 38ms/epoch - 3ms/step
# Epoch 619/1000
# 11/11 - 0s - loss: 0.0014 - 40ms/epoch - 4ms/step
# Epoch 620/1000
# 11/11 - 0s - loss: 0.0014 - 37ms/epoch - 3ms/step
# Epoch 621/1000
# 11/11 - 0s - loss: 0.0014 - 45ms/epoch - 4ms/step
# Epoch 622/1000
# 11/11 - 0s - loss: 0.0014 - 37ms/epoch - 3ms/step
# Epoch 623/1000
# 11/11 - 0s - loss: 0.0014 - 37ms/epoch - 3ms/step
# Epoch 624/1000
# 11/11 - 0s - loss: 0.0014 - 48ms/epoch - 4ms/step
# Epoch 625/1000
# 11/11 - 0s - loss: 0.0014 - 41ms/epoch - 4ms/step
# Epoch 626/1000
# 11/11 - 0s - loss: 0.0014 - 46ms/epoch - 4ms/step
# Epoch 627/1000
# 11/11 - 0s - loss: 0.0015 - 39ms/epoch - 4ms/step
# Epoch 628/1000
# 11/11 - 0s - loss: 0.0014 - 39ms/epoch - 4ms/step
# Epoch 629/1000
# 11/11 - 0s - loss: 0.0014 - 38ms/epoch - 3ms/step
# Epoch 630/1000
# 11/11 - 0s - loss: 0.0014 - 37ms/epoch - 3ms/step
# Epoch 631/1000
# 11/11 - 0s - loss: 0.0015 - 38ms/epoch - 3ms/step
# Epoch 632/1000
# 11/11 - 0s - loss: 0.0015 - 37ms/epoch - 3ms/step
# Epoch 633/1000
# 11/11 - 0s - loss: 0.0014 - 47ms/epoch - 4ms/step
# Epoch 634/1000
# 11/11 - 0s - loss: 0.0015 - 42ms/epoch - 4ms/step
# Epoch 635/1000
# 11/11 - 0s - loss: 0.0015 - 39ms/epoch - 4ms/step
# Epoch 636/1000
# 11/11 - 0s - loss: 0.0014 - 38ms/epoch - 3ms/step
# Epoch 637/1000
# 11/11 - 0s - loss: 0.0015 - 39ms/epoch - 4ms/step
# Epoch 638/1000
# 11/11 - 0s - loss: 0.0013 - 40ms/epoch - 4ms/step
# Epoch 639/1000
# 11/11 - 0s - loss: 0.0014 - 44ms/epoch - 4ms/step
# Epoch 640/1000
# 11/11 - 0s - loss: 0.0014 - 38ms/epoch - 3ms/step
# Epoch 641/1000
# 11/11 - 0s - loss: 0.0014 - 41ms/epoch - 4ms/step
# Epoch 642/1000
# 11/11 - 0s - loss: 0.0014 - 39ms/epoch - 4ms/step
# Epoch 643/1000
# 11/11 - 0s - loss: 0.0014 - 40ms/epoch - 4ms/step
# Epoch 644/1000
# 11/11 - 0s - loss: 0.0014 - 48ms/epoch - 4ms/step
# Epoch 645/1000
# 11/11 - 0s - loss: 0.0015 - 43ms/epoch - 4ms/step
# Epoch 646/1000
# 11/11 - 0s - loss: 0.0013 - 37ms/epoch - 3ms/step
# Epoch 647/1000
# 11/11 - 0s - loss: 0.0013 - 39ms/epoch - 4ms/step
# Epoch 648/1000
# 11/11 - 0s - loss: 0.0013 - 39ms/epoch - 4ms/step
# Epoch 649/1000
# 11/11 - 0s - loss: 0.0017 - 38ms/epoch - 3ms/step
# Epoch 650/1000
# 11/11 - 0s - loss: 0.0017 - 48ms/epoch - 4ms/step
# Epoch 651/1000
# 11/11 - 0s - loss: 0.0014 - 40ms/epoch - 4ms/step
# Epoch 652/1000
# 11/11 - 0s - loss: 0.0014 - 41ms/epoch - 4ms/step
# Epoch 653/1000
# 11/11 - 0s - loss: 0.0014 - 40ms/epoch - 4ms/step
# Epoch 654/1000
# 11/11 - 0s - loss: 0.0015 - 38ms/epoch - 3ms/step
# Epoch 655/1000
# 11/11 - 0s - loss: 0.0013 - 39ms/epoch - 4ms/step
# Epoch 656/1000
# 11/11 - 0s - loss: 0.0014 - 39ms/epoch - 4ms/step
# Epoch 657/1000
# 11/11 - 0s - loss: 0.0013 - 38ms/epoch - 3ms/step
# Epoch 658/1000
# 11/11 - 0s - loss: 0.0014 - 38ms/epoch - 3ms/step
# Epoch 659/1000
# 11/11 - 0s - loss: 0.0014 - 37ms/epoch - 3ms/step
# Epoch 660/1000
# 11/11 - 0s - loss: 0.0013 - 40ms/epoch - 4ms/step
# Epoch 661/1000
# 11/11 - 0s - loss: 0.0014 - 38ms/epoch - 3ms/step
# Epoch 662/1000
# 11/11 - 0s - loss: 0.0013 - 37ms/epoch - 3ms/step
# Epoch 663/1000
# 11/11 - 0s - loss: 0.0013 - 38ms/epoch - 3ms/step
# Epoch 664/1000
# 11/11 - 0s - loss: 0.0014 - 41ms/epoch - 4ms/step
# Epoch 665/1000
# 11/11 - 0s - loss: 0.0013 - 38ms/epoch - 3ms/step
# Epoch 666/1000
# 11/11 - 0s - loss: 0.0014 - 38ms/epoch - 3ms/step
# Epoch 667/1000
# 11/11 - 0s - loss: 0.0013 - 49ms/epoch - 4ms/step
# Epoch 668/1000
# 11/11 - 0s - loss: 0.0013 - 39ms/epoch - 4ms/step
# Epoch 669/1000
# 11/11 - 0s - loss: 0.0013 - 36ms/epoch - 3ms/step
# Epoch 670/1000
# 11/11 - 0s - loss: 0.0014 - 38ms/epoch - 3ms/step
# Epoch 671/1000
# 11/11 - 0s - loss: 0.0013 - 38ms/epoch - 3ms/step
# Epoch 672/1000
# 11/11 - 0s - loss: 0.0013 - 37ms/epoch - 3ms/step
# Epoch 673/1000
# 11/11 - 0s - loss: 0.0013 - 40ms/epoch - 4ms/step
# Epoch 674/1000
# 11/11 - 0s - loss: 0.0013 - 40ms/epoch - 4ms/step
# Epoch 675/1000
# 11/11 - 0s - loss: 0.0013 - 38ms/epoch - 3ms/step
# Epoch 676/1000
# 11/11 - 0s - loss: 0.0014 - 40ms/epoch - 4ms/step
# Epoch 677/1000
# 11/11 - 0s - loss: 0.0014 - 39ms/epoch - 4ms/step
# Epoch 678/1000
# 11/11 - 0s - loss: 0.0015 - 47ms/epoch - 4ms/step
# Epoch 679/1000
# 11/11 - 0s - loss: 0.0014 - 40ms/epoch - 4ms/step
# Epoch 680/1000
# 11/11 - 0s - loss: 0.0015 - 39ms/epoch - 4ms/step
# Epoch 681/1000
# 11/11 - 0s - loss: 0.0014 - 39ms/epoch - 4ms/step
# Epoch 682/1000
# 11/11 - 0s - loss: 0.0014 - 40ms/epoch - 4ms/step
# Epoch 683/1000
# 11/11 - 0s - loss: 0.0013 - 40ms/epoch - 4ms/step
# Epoch 684/1000
# 11/11 - 0s - loss: 0.0013 - 47ms/epoch - 4ms/step
# Epoch 685/1000
# 11/11 - 0s - loss: 0.0013 - 40ms/epoch - 4ms/step
# Epoch 686/1000
# 11/11 - 0s - loss: 0.0013 - 39ms/epoch - 4ms/step
# Epoch 687/1000
# 11/11 - 0s - loss: 0.0013 - 39ms/epoch - 4ms/step
# Epoch 688/1000
# 11/11 - 0s - loss: 0.0015 - 39ms/epoch - 4ms/step
# Epoch 689/1000
# 11/11 - 0s - loss: 0.0013 - 50ms/epoch - 5ms/step
# Epoch 690/1000
# 11/11 - 0s - loss: 0.0013 - 41ms/epoch - 4ms/step
# Epoch 691/1000
# 11/11 - 0s - loss: 0.0013 - 46ms/epoch - 4ms/step
# Epoch 692/1000
# 11/11 - 0s - loss: 0.0014 - 39ms/epoch - 4ms/step
# Epoch 693/1000
# 11/11 - 0s - loss: 0.0013 - 37ms/epoch - 3ms/step
# Epoch 694/1000
# 11/11 - 0s - loss: 0.0015 - 41ms/epoch - 4ms/step
# Epoch 695/1000
# 11/11 - 0s - loss: 0.0014 - 39ms/epoch - 4ms/step
# Epoch 696/1000
# 11/11 - 0s - loss: 0.0014 - 45ms/epoch - 4ms/step
# Epoch 697/1000
# 11/11 - 0s - loss: 0.0015 - 38ms/epoch - 3ms/step
# Epoch 698/1000
# 11/11 - 0s - loss: 0.0013 - 39ms/epoch - 4ms/step
# Epoch 699/1000
# 11/11 - 0s - loss: 0.0013 - 39ms/epoch - 4ms/step
# Epoch 700/1000
# 11/11 - 0s - loss: 0.0013 - 38ms/epoch - 3ms/step
# Epoch 701/1000
# 11/11 - 0s - loss: 0.0013 - 38ms/epoch - 3ms/step
# Epoch 702/1000
# 11/11 - 0s - loss: 0.0013 - 39ms/epoch - 4ms/step
# Epoch 703/1000
# 11/11 - 0s - loss: 0.0013 - 37ms/epoch - 3ms/step
# Epoch 704/1000
# 11/11 - 0s - loss: 0.0013 - 45ms/epoch - 4ms/step
# Epoch 705/1000
# 11/11 - 0s - loss: 0.0013 - 54ms/epoch - 5ms/step
# Epoch 706/1000
# 11/11 - 0s - loss: 0.0013 - 40ms/epoch - 4ms/step
# Epoch 707/1000
# 11/11 - 0s - loss: 0.0013 - 39ms/epoch - 4ms/step
# Epoch 708/1000
# 11/11 - 0s - loss: 0.0015 - 39ms/epoch - 4ms/step
# Epoch 709/1000
# 11/11 - 0s - loss: 0.0013 - 42ms/epoch - 4ms/step
# Epoch 710/1000
# 11/11 - 0s - loss: 0.0013 - 38ms/epoch - 3ms/step
# Epoch 711/1000
# 11/11 - 0s - loss: 0.0013 - 39ms/epoch - 4ms/step
# Epoch 712/1000
# 11/11 - 0s - loss: 0.0015 - 38ms/epoch - 3ms/step
# Epoch 713/1000
# 11/11 - 0s - loss: 0.0014 - 39ms/epoch - 4ms/step
# Epoch 714/1000
# 11/11 - 0s - loss: 0.0013 - 47ms/epoch - 4ms/step
# Epoch 715/1000
# 11/11 - 0s - loss: 0.0013 - 42ms/epoch - 4ms/step
# Epoch 716/1000
# 11/11 - 0s - loss: 0.0013 - 36ms/epoch - 3ms/step
# Epoch 717/1000
# 11/11 - 0s - loss: 0.0013 - 38ms/epoch - 3ms/step
# Epoch 718/1000
# 11/11 - 0s - loss: 0.0014 - 40ms/epoch - 4ms/step
# Epoch 719/1000
# 11/11 - 0s - loss: 0.0013 - 40ms/epoch - 4ms/step
# Epoch 720/1000
# 11/11 - 0s - loss: 0.0013 - 39ms/epoch - 4ms/step
# Epoch 721/1000
# 11/11 - 0s - loss: 0.0013 - 39ms/epoch - 4ms/step
# Epoch 722/1000
# 11/11 - 0s - loss: 0.0013 - 41ms/epoch - 4ms/step
# Epoch 723/1000
# 11/11 - 0s - loss: 0.0013 - 36ms/epoch - 3ms/step
# Epoch 724/1000
# 11/11 - 0s - loss: 0.0013 - 39ms/epoch - 4ms/step
# Epoch 725/1000
# 11/11 - 0s - loss: 0.0013 - 41ms/epoch - 4ms/step
# Epoch 726/1000
# 11/11 - 0s - loss: 0.0013 - 51ms/epoch - 5ms/step
# Epoch 727/1000
# 11/11 - 0s - loss: 0.0013 - 37ms/epoch - 3ms/step
# Epoch 728/1000
# 11/11 - 0s - loss: 0.0013 - 37ms/epoch - 3ms/step
# Epoch 729/1000
# 11/11 - 0s - loss: 0.0013 - 39ms/epoch - 4ms/step
# Epoch 730/1000
# 11/11 - 0s - loss: 0.0013 - 42ms/epoch - 4ms/step
# Epoch 731/1000
# 11/11 - 0s - loss: 0.0014 - 40ms/epoch - 4ms/step
# Epoch 732/1000
# 11/11 - 0s - loss: 0.0014 - 38ms/epoch - 3ms/step
# Epoch 733/1000
# 11/11 - 0s - loss: 0.0013 - 36ms/epoch - 3ms/step
# Epoch 734/1000
# 11/11 - 0s - loss: 0.0013 - 41ms/epoch - 4ms/step
# Epoch 735/1000
# 11/11 - 0s - loss: 0.0013 - 40ms/epoch - 4ms/step
# Epoch 736/1000
# 11/11 - 0s - loss: 0.0013 - 39ms/epoch - 4ms/step
# Epoch 737/1000
# 11/11 - 0s - loss: 0.0013 - 56ms/epoch - 5ms/step
# Epoch 738/1000
# 11/11 - 0s - loss: 0.0013 - 39ms/epoch - 4ms/step
# Epoch 739/1000
# 11/11 - 0s - loss: 0.0014 - 42ms/epoch - 4ms/step
# Epoch 740/1000
# 11/11 - 0s - loss: 0.0013 - 39ms/epoch - 4ms/step
# ...
# Epoch 766/1000
# 11/11 - 0s - loss: 0.0013 - 58ms/epoch - 5ms/step
# Epoch 767/1000
# 11/11 - 0s - loss: 0.0012 - 59ms/epoch - 5ms/step
# Epoch 768/1000
# 11/11 - 0s - loss: 0.0012 - 62ms/epoch - 6ms/step
# Epoch 769/1000
# 11/11 - 0s - loss: 0.0013 - 63ms/epoch - 6ms/step
# Epoch 770/1000
# 11/11 - 0s - loss: 0.0013 - 65ms/epoch - 6ms/step
# Epoch 771/1000
# 11/11 - 0s - loss: 0.0013 - 63ms/epoch - 6ms/step
# Epoch 772/1000
# 11/11 - 0s - loss: 0.0013 - 56ms/epoch - 5ms/step
# Epoch 773/1000
# 11/11 - 0s - loss: 0.0012 - 62ms/epoch - 6ms/step
# Epoch 774/1000
# 11/11 - 0s - loss: 0.0013 - 61ms/epoch - 6ms/step
# Epoch 775/1000
# 11/11 - 0s - loss: 0.0013 - 61ms/epoch - 6ms/step
# Epoch 776/1000
# 11/11 - 0s - loss: 0.0014 - 64ms/epoch - 6ms/step
# Epoch 777/1000
# 11/11 - 0s - loss: 0.0014 - 67ms/epoch - 6ms/step
# Epoch 778/1000
# 11/11 - 0s - loss: 0.0012 - 62ms/epoch - 6ms/step
# Epoch 779/1000
# 11/11 - 0s - loss: 0.0013 - 65ms/epoch - 6ms/step
# Epoch 780/1000
# 11/11 - 0s - loss: 0.0012 - 65ms/epoch - 6ms/step
# Epoch 781/1000
# 11/11 - 0s - loss: 0.0012 - 64ms/epoch - 6ms/step
# Epoch 782/1000
# 11/11 - 0s - loss: 0.0012 - 44ms/epoch - 4ms/step
# Epoch 783/1000
# 11/11 - 0s - loss: 0.0013 - 38ms/epoch - 3ms/step
# Epoch 784/1000
# 11/11 - 0s - loss: 0.0012 - 41ms/epoch - 4ms/step
# Epoch 785/1000
# 11/11 - 0s - loss: 0.0012 - 37ms/epoch - 3ms/step
# Epoch 786/1000
# 11/11 - 0s - loss: 0.0012 - 39ms/epoch - 4ms/step
# Epoch 787/1000
# 11/11 - 0s - loss: 0.0013 - 37ms/epoch - 3ms/step
# Epoch 788/1000
# 11/11 - 0s - loss: 0.0012 - 47ms/epoch - 4ms/step
# Epoch 789/1000
# 11/11 - 0s - loss: 0.0012 - 37ms/epoch - 3ms/step
# Epoch 790/1000
# 11/11 - 0s - loss: 0.0012 - 37ms/epoch - 3ms/step
# Epoch 791/1000
# 11/11 - 0s - loss: 0.0012 - 45ms/epoch - 4ms/step
# Epoch 792/1000
# 11/11 - 0s - loss: 0.0012 - 36ms/epoch - 3ms/step
# Epoch 793/1000
# 11/11 - 0s - loss: 0.0014 - 39ms/epoch - 4ms/step
# Epoch 794/1000
# 11/11 - 0s - loss: 0.0014 - 37ms/epoch - 3ms/step
# Epoch 795/1000
# 11/11 - 0s - loss: 0.0012 - 37ms/epoch - 3ms/step
# Epoch 796/1000
# 11/11 - 0s - loss: 0.0013 - 43ms/epoch - 4ms/step
# Epoch 797/1000
# 11/11 - 0s - loss: 0.0012 - 38ms/epoch - 3ms/step
# Epoch 798/1000
# 11/11 - 0s - loss: 0.0013 - 37ms/epoch - 3ms/step
# Epoch 799/1000
# 11/11 - 0s - loss: 0.0012 - 35ms/epoch - 3ms/step
# Epoch 800/1000
# 11/11 - 0s - loss: 0.0012 - 38ms/epoch - 3ms/step
# Epoch 801/1000
# 11/11 - 0s - loss: 0.0012 - 38ms/epoch - 3ms/step
# Epoch 802/1000
# 11/11 - 0s - loss: 0.0012 - 43ms/epoch - 4ms/step
# Epoch 803/1000
# 11/11 - 0s - loss: 0.0014 - 43ms/epoch - 4ms/step
# Epoch 804/1000
# 11/11 - 0s - loss: 0.0014 - 40ms/epoch - 4ms/step
# Epoch 805/1000
# 11/11 - 0s - loss: 0.0013 - 39ms/epoch - 4ms/step
# Epoch 806/1000
# 11/11 - 0s - loss: 0.0013 - 45ms/epoch - 4ms/step
# Epoch 807/1000
# 11/11 - 0s - loss: 0.0013 - 47ms/epoch - 4ms/step
# Epoch 808/1000
# 11/11 - 0s - loss: 0.0013 - 64ms/epoch - 6ms/step
# Epoch 809/1000
# 11/11 - 0s - loss: 0.0012 - 42ms/epoch - 4ms/step
# Epoch 810/1000
# 11/11 - 0s - loss: 0.0012 - 40ms/epoch - 4ms/step
# Epoch 811/1000
# 11/11 - 0s - loss: 0.0012 - 51ms/epoch - 5ms/step
# Epoch 812/1000
# 11/11 - 0s - loss: 0.0012 - 41ms/epoch - 4ms/step
# Epoch 813/1000
# 11/11 - 0s - loss: 0.0012 - 42ms/epoch - 4ms/step
# Epoch 814/1000
# 11/11 - 0s - loss: 0.0012 - 40ms/epoch - 4ms/step
# Epoch 815/1000
# 11/11 - 0s - loss: 0.0012 - 43ms/epoch - 4ms/step
# Epoch 816/1000
# 11/11 - 0s - loss: 0.0013 - 42ms/epoch - 4ms/step
# Epoch 817/1000
# 11/11 - 0s - loss: 0.0013 - 40ms/epoch - 4ms/step
# Epoch 818/1000
# 11/11 - 0s - loss: 0.0012 - 43ms/epoch - 4ms/step
# Epoch 819/1000
# 11/11 - 0s - loss: 0.0012 - 47ms/epoch - 4ms/step
# Epoch 820/1000
# 11/11 - 0s - loss: 0.0012 - 40ms/epoch - 4ms/step
# Epoch 821/1000
# 11/11 - 0s - loss: 0.0012 - 41ms/epoch - 4ms/step
# Epoch 822/1000
# 11/11 - 0s - loss: 0.0012 - 40ms/epoch - 4ms/step
# Epoch 823/1000
# 11/11 - 0s - loss: 0.0013 - 41ms/epoch - 4ms/step
# Epoch 824/1000
# 11/11 - 0s - loss: 0.0012 - 49ms/epoch - 4ms/step
# Epoch 825/1000
# 11/11 - 0s - loss: 0.0013 - 38ms/epoch - 3ms/step
# Epoch 826/1000
# 11/11 - 0s - loss: 0.0013 - 41ms/epoch - 4ms/step
# Epoch 827/1000
# 11/11 - 0s - loss: 0.0012 - 38ms/epoch - 3ms/step
# Epoch 828/1000
# 11/11 - 0s - loss: 0.0012 - 46ms/epoch - 4ms/step
# Epoch 829/1000
# 11/11 - 0s - loss: 0.0013 - 38ms/epoch - 3ms/step
# Epoch 830/1000
# 11/11 - 0s - loss: 0.0012 - 39ms/epoch - 4ms/step
# Epoch 831/1000
# 11/11 - 0s - loss: 0.0013 - 39ms/epoch - 4ms/step
# Epoch 832/1000
# 11/11 - 0s - loss: 0.0012 - 38ms/epoch - 3ms/step
# Epoch 833/1000
# 11/11 - 0s - loss: 0.0012 - 39ms/epoch - 4ms/step
# Epoch 834/1000
# 11/11 - 0s - loss: 0.0012 - 48ms/epoch - 4ms/step
# Epoch 835/1000
# 11/11 - 0s - loss: 0.0014 - 43ms/epoch - 4ms/step
# Epoch 836/1000
# 11/11 - 0s - loss: 0.0015 - 40ms/epoch - 4ms/step
# Epoch 837/1000
# 11/11 - 0s - loss: 0.0014 - 39ms/epoch - 4ms/step
# Epoch 838/1000
# 11/11 - 0s - loss: 0.0013 - 41ms/epoch - 4ms/step
# Epoch 839/1000
# 11/11 - 0s - loss: 0.0013 - 38ms/epoch - 3ms/step
# Epoch 840/1000
# 11/11 - 0s - loss: 0.0013 - 40ms/epoch - 4ms/step
# Epoch 841/1000
# 11/11 - 0s - loss: 0.0012 - 39ms/epoch - 4ms/step
# Epoch 842/1000
# 11/11 - 0s - loss: 0.0012 - 44ms/epoch - 4ms/step
# Epoch 843/1000
# 11/11 - 0s - loss: 0.0012 - 40ms/epoch - 4ms/step
# Epoch 844/1000
# 11/11 - 0s - loss: 0.0016 - 47ms/epoch - 4ms/step
# Epoch 845/1000
# 11/11 - 0s - loss: 0.0018 - 40ms/epoch - 4ms/step
# Epoch 846/1000
# 11/11 - 0s - loss: 0.0013 - 39ms/epoch - 4ms/step
# Epoch 847/1000
# 11/11 - 0s - loss: 0.0012 - 42ms/epoch - 4ms/step
# Epoch 848/1000
# 11/11 - 0s - loss: 0.0013 - 36ms/epoch - 3ms/step
# Epoch 849/1000
# 11/11 - 0s - loss: 0.0016 - 38ms/epoch - 3ms/step
# Epoch 850/1000
# 11/11 - 0s - loss: 0.0013 - 43ms/epoch - 4ms/step
# Epoch 851/1000
# 11/11 - 0s - loss: 0.0014 - 39ms/epoch - 4ms/step
# Epoch 852/1000
# 11/11 - 0s - loss: 0.0012 - 40ms/epoch - 4ms/step
# Epoch 853/1000
# 11/11 - 0s - loss: 0.0012 - 44ms/epoch - 4ms/step
# Epoch 854/1000
# 11/11 - 0s - loss: 0.0014 - 37ms/epoch - 3ms/step
# Epoch 855/1000
# 11/11 - 0s - loss: 0.0013 - 37ms/epoch - 3ms/step
# Epoch 856/1000
# 11/11 - 0s - loss: 0.0012 - 39ms/epoch - 4ms/step
# Epoch 857/1000
# 11/11 - 0s - loss: 0.0012 - 45ms/epoch - 4ms/step
# Epoch 858/1000
# 11/11 - 0s - loss: 0.0012 - 38ms/epoch - 3ms/step
# Epoch 859/1000
# 11/11 - 0s - loss: 0.0012 - 41ms/epoch - 4ms/step
# Epoch 860/1000
# 11/11 - 0s - loss: 0.0012 - 40ms/epoch - 4ms/step
# Epoch 861/1000
# 11/11 - 0s - loss: 0.0012 - 37ms/epoch - 3ms/step
# Epoch 862/1000
# 11/11 - 0s - loss: 0.0012 - 39ms/epoch - 4ms/step
# Epoch 863/1000
# 11/11 - 0s - loss: 0.0012 - 38ms/epoch - 3ms/step
# Epoch 864/1000
# 11/11 - 0s - loss: 0.0012 - 49ms/epoch - 4ms/step
# Epoch 865/1000
# 11/11 - 0s - loss: 0.0012 - 42ms/epoch - 4ms/step
# Epoch 866/1000
# 11/11 - 0s - loss: 0.0014 - 39ms/epoch - 4ms/step
# Epoch 867/1000
# 11/11 - 0s - loss: 0.0014 - 40ms/epoch - 4ms/step
# Epoch 868/1000
# 11/11 - 0s - loss: 0.0012 - 42ms/epoch - 4ms/step
# Epoch 869/1000
# 11/11 - 0s - loss: 0.0012 - 40ms/epoch - 4ms/step
# Epoch 870/1000
# 11/11 - 0s - loss: 0.0012 - 41ms/epoch - 4ms/step
# Epoch 871/1000
# 11/11 - 0s - loss: 0.0013 - 48ms/epoch - 4ms/step
# Epoch 872/1000
# 11/11 - 0s - loss: 0.0016 - 40ms/epoch - 4ms/step
# Epoch 873/1000
# 11/11 - 0s - loss: 0.0015 - 42ms/epoch - 4ms/step
# Epoch 874/1000
# 11/11 - 0s - loss: 0.0012 - 39ms/epoch - 4ms/step
# Epoch 875/1000
# 11/11 - 0s - loss: 0.0012 - 43ms/epoch - 4ms/step
# Epoch 876/1000
# 11/11 - 0s - loss: 0.0012 - 38ms/epoch - 3ms/step
# Epoch 877/1000
# 11/11 - 0s - loss: 0.0012 - 39ms/epoch - 4ms/step
# Epoch 878/1000
# 11/11 - 0s - loss: 0.0012 - 43ms/epoch - 4ms/step
# Epoch 879/1000
# 11/11 - 0s - loss: 0.0012 - 44ms/epoch - 4ms/step
# Epoch 880/1000
# 11/11 - 0s - loss: 0.0012 - 47ms/epoch - 4ms/step
# Epoch 881/1000
# 11/11 - 0s - loss: 0.0012 - 39ms/epoch - 4ms/step
# Epoch 882/1000
# 11/11 - 0s - loss: 0.0012 - 41ms/epoch - 4ms/step
# Epoch 883/1000
# 11/11 - 0s - loss: 0.0014 - 40ms/epoch - 4ms/step
# Epoch 884/1000
# 11/11 - 0s - loss: 0.0012 - 47ms/epoch - 4ms/step
# Epoch 885/1000
# 11/11 - 0s - loss: 0.0012 - 39ms/epoch - 4ms/step
# Epoch 886/1000
# 11/11 - 0s - loss: 0.0012 - 40ms/epoch - 4ms/step
# Epoch 887/1000
# 11/11 - 0s - loss: 0.0012 - 40ms/epoch - 4ms/step
# Epoch 888/1000
# 11/11 - 0s - loss: 0.0012 - 39ms/epoch - 4ms/step
# Epoch 889/1000
# 11/11 - 0s - loss: 0.0013 - 45ms/epoch - 4ms/step
# Epoch 890/1000
# 11/11 - 0s - loss: 0.0015 - 39ms/epoch - 4ms/step
# Epoch 891/1000
# 11/11 - 0s - loss: 0.0012 - 39ms/epoch - 4ms/step
# Epoch 892/1000
# 11/11 - 0s - loss: 0.0012 - 42ms/epoch - 4ms/step
# Epoch 893/1000
# 11/11 - 0s - loss: 0.0012 - 39ms/epoch - 4ms/step
# Epoch 894/1000
# 11/11 - 0s - loss: 0.0012 - 38ms/epoch - 3ms/step
# Epoch 895/1000
# 11/11 - 0s - loss: 0.0012 - 46ms/epoch - 4ms/step
# Epoch 896/1000
# 11/11 - 0s - loss: 0.0013 - 46ms/epoch - 4ms/step
# Epoch 897/1000
# 11/11 - 0s - loss: 0.0013 - 41ms/epoch - 4ms/step
# Epoch 898/1000
# 11/11 - 0s - loss: 0.0012 - 38ms/epoch - 3ms/step
# Epoch 899/1000
# 11/11 - 0s - loss: 0.0013 - 43ms/epoch - 4ms/step
# Epoch 900/1000
# 11/11 - 0s - loss: 0.0012 - 49ms/epoch - 4ms/step
# Epoch 901/1000
# 11/11 - 0s - loss: 0.0012 - 43ms/epoch - 4ms/step
# Epoch 902/1000
# 11/11 - 0s - loss: 0.0012 - 45ms/epoch - 4ms/step
# Epoch 903/1000
# 11/11 - 0s - loss: 0.0012 - 43ms/epoch - 4ms/step
# Epoch 904/1000
# 11/11 - 0s - loss: 0.0013 - 39ms/epoch - 4ms/step
# Epoch 905/1000
# 11/11 - 0s - loss: 0.0012 - 42ms/epoch - 4ms/step
# Epoch 906/1000
# 11/11 - 0s - loss: 0.0012 - 43ms/epoch - 4ms/step
# Epoch 907/1000
# 11/11 - 0s - loss: 0.0011 - 40ms/epoch - 4ms/step
# Epoch 908/1000
# 11/11 - 0s - loss: 0.0012 - 38ms/epoch - 3ms/step
# Epoch 909/1000
# 11/11 - 0s - loss: 0.0012 - 45ms/epoch - 4ms/step
# Epoch 910/1000
# 11/11 - 0s - loss: 0.0012 - 40ms/epoch - 4ms/step
# Epoch 911/1000
# 11/11 - 0s - loss: 0.0012 - 39ms/epoch - 4ms/step
# Epoch 912/1000
# 11/11 - 0s - loss: 0.0013 - 41ms/epoch - 4ms/step
# Epoch 913/1000
# 11/11 - 0s - loss: 0.0012 - 40ms/epoch - 4ms/step
# Epoch 914/1000
# 11/11 - 0s - loss: 0.0015 - 40ms/epoch - 4ms/step
# Epoch 915/1000
# 11/11 - 0s - loss: 0.0012 - 39ms/epoch - 4ms/step
# Epoch 916/1000
# 11/11 - 0s - loss: 0.0013 - 39ms/epoch - 4ms/step
# Epoch 917/1000
# 11/11 - 0s - loss: 0.0013 - 48ms/epoch - 4ms/step
# Epoch 918/1000
# 11/11 - 0s - loss: 0.0012 - 62ms/epoch - 6ms/step
# Epoch 919/1000
# 11/11 - 0s - loss: 0.0012 - 41ms/epoch - 4ms/step
# Epoch 920/1000
# 11/11 - 0s - loss: 0.0012 - 40ms/epoch - 4ms/step
# Epoch 921/1000
# 11/11 - 0s - loss: 0.0012 - 42ms/epoch - 4ms/step
# Epoch 922/1000
# 11/11 - 0s - loss: 0.0011 - 44ms/epoch - 4ms/step
# Epoch 923/1000
# 11/11 - 0s - loss: 0.0011 - 40ms/epoch - 4ms/step
# Epoch 924/1000
# 11/11 - 0s - loss: 0.0012 - 40ms/epoch - 4ms/step
# Epoch 925/1000
# 11/11 - 0s - loss: 0.0011 - 49ms/epoch - 4ms/step
# Epoch 926/1000
# 11/11 - 0s - loss: 0.0011 - 48ms/epoch - 4ms/step
# Epoch 927/1000
# 11/11 - 0s - loss: 0.0012 - 41ms/epoch - 4ms/step
# Epoch 928/1000
# 11/11 - 0s - loss: 0.0012 - 39ms/epoch - 4ms/step
# Epoch 929/1000
# 11/11 - 0s - loss: 0.0012 - 39ms/epoch - 4ms/step
# Epoch 930/1000
# 11/11 - 0s - loss: 0.0013 - 39ms/epoch - 4ms/step
# Epoch 931/1000
# 11/11 - 0s - loss: 0.0012 - 39ms/epoch - 4ms/step
# Epoch 932/1000
# 11/11 - 0s - loss: 0.0011 - 38ms/epoch - 3ms/step
# Epoch 933/1000
# 11/11 - 0s - loss: 0.0011 - 46ms/epoch - 4ms/step
# Epoch 934/1000
# 11/11 - 0s - loss: 0.0012 - 39ms/epoch - 4ms/step
# Epoch 935/1000
# 11/11 - 0s - loss: 0.0013 - 43ms/epoch - 4ms/step
# Epoch 936/1000
# 11/11 - 0s - loss: 0.0013 - 39ms/epoch - 4ms/step
# Epoch 937/1000
# 11/11 - 0s - loss: 0.0011 - 38ms/epoch - 3ms/step
# Epoch 938/1000
# 11/11 - 0s - loss: 0.0013 - 39ms/epoch - 4ms/step
# Epoch 939/1000
# 11/11 - 0s - loss: 0.0012 - 45ms/epoch - 4ms/step
# Epoch 940/1000
# 11/11 - 0s - loss: 0.0013 - 39ms/epoch - 4ms/step
# Epoch 941/1000
# 11/11 - 0s - loss: 0.0012 - 43ms/epoch - 4ms/step
# Epoch 942/1000
# 11/11 - 0s - loss: 0.0012 - 40ms/epoch - 4ms/step
# Epoch 943/1000
# 11/11 - 0s - loss: 0.0012 - 38ms/epoch - 3ms/step
# Epoch 944/1000
# 11/11 - 0s - loss: 0.0012 - 39ms/epoch - 4ms/step
# Epoch 945/1000
# 11/11 - 0s - loss: 0.0012 - 41ms/epoch - 4ms/step
# Epoch 946/1000
# 11/11 - 0s - loss: 0.0012 - 41ms/epoch - 4ms/step
# Epoch 947/1000
# 11/11 - 0s - loss: 0.0012 - 38ms/epoch - 3ms/step
# Epoch 948/1000
# 11/11 - 0s - loss: 0.0011 - 48ms/epoch - 4ms/step
# Epoch 949/1000
# 11/11 - 0s - loss: 0.0012 - 40ms/epoch - 4ms/step
# Epoch 950/1000
# 11/11 - 0s - loss: 0.0012 - 46ms/epoch - 4ms/step
# Epoch 951/1000
# 11/11 - 0s - loss: 0.0012 - 40ms/epoch - 4ms/step
# Epoch 952/1000
# 11/11 - 0s - loss: 0.0011 - 44ms/epoch - 4ms/step
# Epoch 953/1000
# 11/11 - 0s - loss: 0.0011 - 40ms/epoch - 4ms/step
# Epoch 954/1000
# 11/11 - 0s - loss: 0.0012 - 41ms/epoch - 4ms/step
# Epoch 955/1000
# 11/11 - 0s - loss: 0.0012 - 39ms/epoch - 4ms/step
# Epoch 956/1000
# 11/11 - 0s - loss: 0.0011 - 40ms/epoch - 4ms/step
# Epoch 957/1000
# 11/11 - 0s - loss: 0.0011 - 38ms/epoch - 3ms/step
# Epoch 958/1000
# 11/11 - 0s - loss: 0.0011 - 38ms/epoch - 3ms/step
# Epoch 959/1000
# 11/11 - 0s - loss: 0.0015 - 47ms/epoch - 4ms/step
# Epoch 960/1000
# 11/11 - 0s - loss: 0.0017 - 40ms/epoch - 4ms/step
# Epoch 961/1000
# 11/11 - 0s - loss: 0.0016 - 40ms/epoch - 4ms/step
# Epoch 962/1000
# 11/11 - 0s - loss: 0.0013 - 39ms/epoch - 4ms/step
# Epoch 963/1000
# 11/11 - 0s - loss: 0.0011 - 38ms/epoch - 3ms/step
# Epoch 964/1000
# 11/11 - 0s - loss: 0.0012 - 38ms/epoch - 3ms/step
# Epoch 965/1000
# 11/11 - 0s - loss: 0.0012 - 38ms/epoch - 3ms/step
# Epoch 966/1000
# 11/11 - 0s - loss: 0.0011 - 39ms/epoch - 4ms/step
# Epoch 967/1000
# 11/11 - 0s - loss: 0.0012 - 39ms/epoch - 4ms/step
# Epoch 968/1000
# 11/11 - 0s - loss: 0.0012 - 41ms/epoch - 4ms/step
# Epoch 969/1000
# 11/11 - 0s - loss: 0.0014 - 37ms/epoch - 3ms/step
# Epoch 970/1000
# 11/11 - 0s - loss: 0.0012 - 40ms/epoch - 4ms/step
# Epoch 971/1000
# 11/11 - 0s - loss: 0.0012 - 41ms/epoch - 4ms/step
# Epoch 972/1000
# 11/11 - 0s - loss: 0.0013 - 45ms/epoch - 4ms/step
# Epoch 973/1000
# 11/11 - 0s - loss: 0.0012 - 41ms/epoch - 4ms/step
# Epoch 974/1000
# 11/11 - 0s - loss: 0.0012 - 38ms/epoch - 3ms/step
# Epoch 975/1000
# 11/11 - 0s - loss: 0.0013 - 43ms/epoch - 4ms/step
# Epoch 976/1000
# 11/11 - 0s - loss: 0.0011 - 48ms/epoch - 4ms/step
# Epoch 977/1000
# 11/11 - 0s - loss: 0.0012 - 47ms/epoch - 4ms/step
# Epoch 978/1000
# 11/11 - 0s - loss: 0.0012 - 42ms/epoch - 4ms/step
# Epoch 979/1000
# 11/11 - 0s - loss: 0.0013 - 40ms/epoch - 4ms/step
# Epoch 980/1000
# 11/11 - 0s - loss: 0.0011 - 39ms/epoch - 4ms/step
# Epoch 981/1000
# 11/11 - 0s - loss: 0.0011 - 39ms/epoch - 4ms/step
# Epoch 982/1000
# 11/11 - 0s - loss: 0.0011 - 39ms/epoch - 4ms/step
# Epoch 983/1000
# 11/11 - 0s - loss: 0.0011 - 47ms/epoch - 4ms/step
# Epoch 984/1000
# 11/11 - 0s - loss: 0.0013 - 40ms/epoch - 4ms/step
# Epoch 985/1000
# 11/11 - 0s - loss: 0.0012 - 38ms/epoch - 3ms/step
# Epoch 986/1000
# 11/11 - 0s - loss: 0.0012 - 41ms/epoch - 4ms/step
# Epoch 987/1000
# 11/11 - 0s - loss: 0.0011 - 40ms/epoch - 4ms/step
# Epoch 988/1000
# 11/11 - 0s - loss: 0.0012 - 39ms/epoch - 4ms/step
# Epoch 989/1000
# 11/11 - 0s - loss: 0.0012 - 37ms/epoch - 3ms/step
# Epoch 990/1000
# 11/11 - 0s - loss: 0.0011 - 42ms/epoch - 4ms/step
# Epoch 991/1000
# 11/11 - 0s - loss: 0.0011 - 41ms/epoch - 4ms/step
# Epoch 992/1000
# 11/11 - 0s - loss: 0.0011 - 39ms/epoch - 4ms/step
# Epoch 993/1000
# 11/11 - 0s - loss: 0.0011 - 40ms/epoch - 4ms/step
# Epoch 994/1000
# 11/11 - 0s - loss: 0.0012 - 48ms/epoch - 4ms/step
# Epoch 995/1000
# 11/11 - 0s - loss: 0.0012 - 41ms/epoch - 4ms/step
# Epoch 996/1000
# 11/11 - 0s - loss: 0.0014 - 40ms/epoch - 4ms/step
# Epoch 997/1000
# 11/11 - 0s - loss: 0.0013 - 41ms/epoch - 4ms/step
# Epoch 998/1000
# 11/11 - 0s - loss: 0.0012 - 40ms/epoch - 4ms/step
# Epoch 999/1000
# 11/11 - 0s - loss: 0.0011 - 45ms/epoch - 4ms/step
# Epoch 1000/1000
# 11/11 - 0s - loss: 0.0011 - 39ms/epoch - 4ms/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 4)                 68
#
#  dense (Dense)               (None, 1)                 5
#
# =================================================================
# Total params: 73
# Trainable params: 73
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 1.3 Evaluate Predictive Model Performance (10 Points)
#
# Predict datapoints with the observed datapoints and trained model.
#
# **Tasks:**
# 1. Do direct prediction on train and test datapoints with the obtained model in section 1.2. **(2 Points)**
# 2. Scale the prediction results back to original representation with the scaler.(scaler.inverse_transform function) **(3 Points)**
# 3. Calculate root mean squared error (RMSE) and **print out** the error for **both TRAIN and TEST**. **(3 Points)**
# 4. **Plot** the **TEST** label and prediction. **(2 Points)**
#
#
# **Hints:**
# 1. Scale back the predictions with the build-in function "scaler.inverse_transform".\
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html#sklearn.preprocessing.MinMaxScaler.inverse_transform
# 2. For validation: Train Score: **~10.92 RMSE** Test Score: **~27.70 RMSE**
# 3. The plot for validation is shown below (observation test data are blue and prediction results are orange):
#
#
# ![](https://drive.google.com/uc?export=view&id=10c1Fsa_9v0AQf2fDpCzGPFPxbIEso81u)

# %%
### Make Predictions ###

trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# Out:
# 4/4 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 17ms/step

# %%
### Scale Back Predictions ###

trainPredict = scaler.inverse_transform(trainPredict) # scale train prediction back with scaler.inverse_transform()
print(trainY.shape)
trainY = scaler.inverse_transform([trainY])  # scale train labels back with scaler.inverse_transform()

testPredict = scaler.inverse_transform(testPredict) # scale test prediction back with scaler.inverse_transform()
testY = scaler.inverse_transform([testY]) # scale test labels back with scaler.inverse_transform()
# Out:
# (101,)

# %%
### Calculate Root Mean Squared Error (RMSE) ###
import math
from sklearn.metrics import mean_squared_error # Import mean_squared_error from sklearn.metrics

trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0])) 
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 12.18 RMSE
# Test Score: 27.50 RMSE

# %%
### Plot Observation Data and Prediction Results with TEST dataset ###

import matplotlib.pyplot as plt
plt.plot(testY[0]) # Plot Observations in Test Set
plt.plot(testPredict) # Plot Predictions in Test Set

plt.show()

# %% [markdown]
# ## 2 - Build an LSTM model to conduct sentiment analysis ##
#
# ### 2.1 Prepare the data (13 Points) ###
#
# Prepare IMDB data for reccurent neural network training.
#
# **Tasks:**
# 1. Load the data from IMDB review dataset and **print out** the lengths of sequences. **(3 Points)**
# 2. Preprocess review data to meet the network input requirement by specifying **number of words=1000**, setting **the analysis length of the review = 100**, and **padding the input sequences**. **(10 Points)**
#
# **Hints:**
# 1. You may load the IMDB data with keras.datasets.imdb.load_data(num_words=max_features). Here. max_features is set to **1000**.
# 2. You may use keras.preprocessing.sequence.pad_sequences(x_train, maxlen) to pad the input sequences and set maxlen to **100**.
#
# **Note:**\
# We train the built LSTM-based model with ALL training data; the **validation set** (aka **development set**) is set with the **testing set** for model evaluation. This split is common in the application with limited sampled observation data, like NLP problems.

# %%
import tensorflow as tf
import tensorflow.keras as keras
from keras import layers
import random
import numpy as np


### Set random seed to ensure deterministic results
import os
seed_value = 1
os.environ['PYTHONHASHSEED']=str(seed_value)
def reset_random_seeds():
   tf.random.set_seed(seed_value)
   np.random.seed(seed_value)
   random.seed(seed_value)

reset_random_seeds() # randomly set initial data

# %%
# Prepare the data here

max_features = 1000 # Only consider the top 1k words
maxlen = 100 # Only consider the first 100 words of each movie review

(x_train, y_train), (x_val, y_val) = keras.datasets.imdb.load_data(num_words=max_features) # load IMDB data with specified num_words = 1000; testing set is set to validation set.
print(len(x_train), "Training sequences")
print(len(x_val), "Validation sequences")
# print(x_train)
# print(y_train)
x_train = keras.preprocessing.sequence.pad_sequences(x_train, maxlen=maxlen) # Pad IMDB training data with specified maxlen=100
x_val = keras.preprocessing.sequence.pad_sequences(x_val, maxlen=maxlen) # Pad IMDB validation data with specified maxlen=100
print('x_train shape:', x_train.shape)
print('x_val shape:', x_val.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 0s 0us/step
# 25000 Training sequences
# 25000 Validation sequences
# x_train shape: (25000, 100)
# x_val shape: (25000, 100)

# %% [markdown]
# ### 2.2 - Design and train LSTM model (25 Points) ###
#
# Build an LSTM model.
#
# **Tasks:**
# 1. Build the LSTM model with **1 embedding layer**, **1 LSTM layer**, and **1 Dense layer**. **Print out** model summary. The embedding vector is specified with the dimension of **8**. **(10 Points)**
# 2. Compile the LSTM model with **Adam** optimizer, **binary_crossentropy** loss function, and **accuracy** metrics. **(5 Points)**
# 3. Train the LSTM model with **batch_size=64 for 10 epochs** and report **training and validation accuracies over epochs**. **(5 Points)**
# 4. **Print out** best validation accuracy. **(5 Points)**
#
#
#
# **Hints:**
# 1. Set input dimension to **1000** and output dimension to **8** for embedding layer.
# 2. Set **unit_size=8** for LSTM layer.
# 3. Set activation function to **sigmoid** for Dense layer.
# 4. For validation: the outputs for first epoch might be like （but not need to be exactly） the statistics below:\
# - **- loss: 0.5679 - accuracy: 0.7068 - val_loss: 0.4441 - val_accuracy: 0.8072**
# 5. The model summary is as follows:
# - Total params: 8,553
# - Trainable params: 8,553
# - Non-trainable params: 0
#
# **Useful Reference:**
# 1. https://keras.io/examples/nlp/bidirectional_lstm_imdb/

# %%
### Model design with Embedding and LSTM layers ####
inputs = keras.Input(shape=(None,), dtype="int32") # This is an easy way to set an adaptive length for input sequence
# Embed each integer in a 8-dimensional vector
x = layers.Embedding(max_features, 8)(inputs) # Embed data in an 8-dimensional vector
x = layers.LSTM(8)(x) # Add 1st layer of LSTM with 8 hidden states (aka units)
outputs = layers.Dense(1, activation="sigmoid")(x) # Add a classifier with units=1 and activation="sigmoid"

### Clear cached model to refresh memory and build new model for training ###
keras.backend.clear_session() # Clear cached model
model = keras.Model(inputs, outputs) # Build new keras model
model.summary() # Print out model summary

model.compile("adam", "binary_crossentropy", metrics=["accuracy"]) # Compile built model with "adam", "binary_crossentropy", and metrics=["accuracy"]
model.fit(x_train, y_train, batch_size=64, epochs=10, validation_data=(x_val, y_val)) # Train the compiled model with model.fit()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None)]            0
#
#  embedding (Embedding)       (None, None, 8)           8000
#
#  lstm (LSTM)                 (None, 8)                 544
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 8,553
# Trainable params: 8,553
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 20s 43ms/step - loss: 0.5693 - accuracy: 0.7073 - val_loss: 0.4342 - val_accuracy: 0.8101
# Epoch 2/10
# 391/391 [==============================] - 6s 15ms/step - loss: 0.4025 - accuracy: 0.8235 - val_loss: 0.3923 - val_accuracy: 0.8262
# Epoch 3/10
# 391/391 [==============================] - 5s 12ms/step - loss: 0.3742 - accuracy: 0.8370 - val_loss: 0.3795 - val_accuracy: 0.8278
# Epoch 4/10
# 391/391 [==============================] - 4s 11ms/step - loss: 0.3614 - accuracy: 0.8433 - val_loss: 0.3846 - val_accuracy: 0.8242
# Epoch 5/10
# 391/391 [==============================] - 5s 14ms/step - loss: 0.3554 - accuracy: 0.8468 - val_loss: 0.3777 - val_accuracy: 0.8315
# Epoch 6/10
# 391/391 [==============================] - 4s 10ms/step - loss: 0.3527 - accuracy: 0.8479 - val_loss: 0.4456 - val_accuracy: 0.8122
# Epoch 7/10
# 391/391 [==============================] - 5s 13ms/step - loss: 0.3454 - accuracy: 0.8480 - val_loss: 0.3725 - val_accuracy: 0.8317
# Epoch 8/10
# 391/391 [==============================] - 4s 11ms/step - loss: 0.3407 - accuracy: 0.8505 - val_loss: 0.3751 - val_accuracy: 0.8298
# Epoch 9/10
# 391/391 [==============================] - 4s 10ms/step - loss: 0.3353 - accuracy: 0.8532 - val_loss: 0.3855 - val_accuracy: 0.8310
# Epoch 10/10
# 391/391 [==============================] - 5s 12ms/step - loss: 0.3310 - accuracy: 0.8552 - val_loss: 0.3782 - val_accuracy: 0.8311

# %% [markdown]
# ### 2.3 - LSTM hyperparameter tuning (Bonus 15 Points) ###
#
# Boost the performance of obtained LSTM (aka vanilla model) by hyperparameter tuning.
#
# **Tasks:**
# Note:
# - All modificiations are directly conducted based on the vanilla model above (from 2.2).
# - For each scenario, **report <span style="color:red"> BEST Validation Accuracy </span> and generate Training/Validation <span style="color:red"> Accuracy plots over epochs</span>**. You may just paste the plot figures in the cells with **Markdown mode**, or leave the result after running. **Make sure it is already correctly shown in your submitted file.**
# 1.  Scenario 1 (**5 points**):
#     - Add one additional LSTM layer (totally 2 LSTM layers).
#     - Modify the embedding dimension to 16.
#     - Modify the units of LSTM to 16.
# 2. Scenario 2 (**5 points**)
#     - Add one additional LSTM layer (totally 2 LSTM layers).
#     - Modify the embedding dimension to 128.
#     - Modify the units of LSTM to 128.
# 3. Scenario 3 (**5 points**)
#     - Add one additional LSTM layer (totally 2 LSTM layers).
#     - Modify the embedding dimension to 128.
#     - Modify the units of LSTM to 128.
#     - Increase analysis length for review data to maxlen = 200
#
# **Hints:**
# For validation: the outputs for first few epoches might be like （but not need to be exactly） the statistics below:
# - Scenario 1: **loss: 0.4968 - accuracy: 0.7450 - val_loss: 0.4079 - val_accuracy: 0.8198**
# - Scenario 2: **loss: 0.3883 - accuracy: 0.8286 - val_loss: 0.3844 - val_accuracy: 0.8242**
# - Scenario 3: **loss: 0.3688 - accuracy: 0.8382 - val_loss: 0.3692 - val_accuracy: 0.8333**
#
# - Summary of Model 1: Total params: 20,241; Trainable params: 20,241; Non-trainable params: 0
# - Summary of Model 2: Total params: 391,297; Trainable params: 391,297; Non-trainable params: 0
# - Summary of Model 3: Total params: 391,297; Trainable params: 391,297; Non-trainable params: 0
#
# You may follow the example from the reference below to add additional LSTM layer.
#
# **Useful Reference:**
# 1. https://keras.io/examples/nlp/bidirectional_lstm_imdb/

# %%
########################### Scenario 1 ###########################
##################################################################

### Set random seed to ensure deterministic results ###
import os
seed_value = 1
os.environ['PYTHONHASHSEED']=str(seed_value)
def reset_random_seeds():
   tf.random.set_seed(seed_value)
   np.random.seed(seed_value)
   random.seed(seed_value)

reset_random_seeds() # randomly set initial data

max_features = 1000 # Only consider the top 1k words
maxlen = 100 # Only consider the first 100 words of each movie review

### Model design with Embedding and LSTM layers ####
inputs = keras.Input(shape=(None,), dtype="int32") # This is an easy way to set an adaptive length for input sequence
# Embed each integer in a 16-dimensional vector
x = layers.Embedding(max_features, 16)(inputs) # Embed data in a 16-dimensional vector
x = layers.LSTM(16, return_sequences=True)(x) # Add 1st layer of LSTM with 16 hidden states (aka units); set return_sequences=true.
x = layers.LSTM(16)(x) # Add 2nd layer of LSTM with 16 hidden states (aka units)
outputs = layers.Dense(1, activation="sigmoid")(x) # Add a classifier with units=1 and activation="sigmoid"

### Clear cached model to refresh memory and build new model for training ###
keras.backend.clear_session() # Clear cached model
model = keras.Model(inputs, outputs) # Build new keras model
model.summary() # Print out model summary

model.compile("adam", "binary_crossentropy", metrics=["accuracy"]) # Compile built model with "adam", "binary_crossentropy", and metrics=["accuracy"]
history = model.fit(x_train, y_train, batch_size=64, epochs=10, validation_data=(x_val, y_val)) # Train the compiled model using model.fit() with batch_size=64, epochs=10, and validation_data=(x_val, y_val)

### Report BEST Validation Accuracy and generate Training/Validation Accuracy plots over epochs ###
import matplotlib.pyplot as plt

# list all data in history
print(history.history.keys())

loss = history.history['loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = range(len(loss))

plt.title("Scenario 1 Training and Validation Accuracy")
plt.plot(epochs, acc, "-b", label="Training Accuracy")
plt.plot(epochs, val_acc, "-r", label="Validation Accuracy")
plt.show()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None)]            0
#
#  embedding (Embedding)       (None, None, 16)          16000
#
#  lstm (LSTM)                 (None, None, 16)          2112
#
#  lstm_1 (LSTM)               (None, 16)                2112
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 20,241
# Trainable params: 20,241
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 19s 38ms/step - loss: 0.4837 - accuracy: 0.7570 - val_loss: 0.4096 - val_accuracy: 0.8198
# Epoch 2/10
# 391/391 [==============================] - 8s 21ms/step - loss: 0.3890 - accuracy: 0.8281 - val_loss: 0.3833 - val_accuracy: 0.8270
# Epoch 3/10
# 391/391 [==============================] - 6s 16ms/step - loss: 0.3728 - accuracy: 0.8366 - val_loss: 0.3720 - val_accuracy: 0.8325
# Epoch 4/10
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3616 - accuracy: 0.8411 - val_loss: 0.3834 - val_accuracy: 0.8245
# Epoch 5/10
# 391/391 [==============================] - 7s 19ms/step - loss: 0.3554 - accuracy: 0.8429 - val_loss: 0.3700 - val_accuracy: 0.8324
# Epoch 6/10
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3486 - accuracy: 0.8456 - val_loss: 0.4265 - val_accuracy: 0.8173
# Epoch 7/10
# 391/391 [==============================] - 9s 23ms/step - loss: 0.3386 - accuracy: 0.8482 - val_loss: 0.3688 - val_accuracy: 0.8334
# Epoch 8/10
# 391/391 [==============================] - 6s 14ms/step - loss: 0.3317 - accuracy: 0.8532 - val_loss: 0.3746 - val_accuracy: 0.8292
# Epoch 9/10
# 391/391 [==============================] - 6s 16ms/step - loss: 0.3233 - accuracy: 0.8543 - val_loss: 0.3798 - val_accuracy: 0.8313
# Epoch 10/10
# 391/391 [==============================] - 5s 14ms/step - loss: 0.3181 - accuracy: 0.8597 - val_loss: 0.4036 - val_accuracy: 0.8290
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# **Scenario 1 Training/Validation Accuracy plots over epochs plot inserted with Markdown mode**
#
# ![scenario1.JPG](data:image/jpeg;base64,...)

# %%
########################### Scenario 2 ###########################
##################################################################

### Set random seed to ensure deterministic results ###
import os
seed_value = 1
os.environ['PYTHONHASHSEED']=str(seed_value)
def reset_random_seeds():
   tf.random.set_seed(seed_value)
   np.random.seed(seed_value)
   random.seed(seed_value)

reset_random_seeds() # randomly set initial data

max_features = 1000 # Only consider the top 1k words
maxlen = 100 # Only consider the first 100 words of each movie review

### Model design with Embedding and LSTM layers ####
inputs = keras.Input(shape=(None,), dtype="int32") # This is an easy way to set an adaptive length for input sequence
# Embed each integer in a 128-dimensional vector
x = layers.Embedding(max_features, 128)(inputs) # Embed data in a 128-dimensional vector
x = layers.LSTM(128, return_sequences=True )(x) # Add 1st layer of LSTM with 128 hidden states (aka units); set return_sequences=true.
x = layers.LSTM(128)(x) # Add 2nd layer of LSTM with 128 hidden states (aka units)
outputs = layers.Dense(1, activation="sigmoid")(x) # Add a classifier with units=1 and activation="sigmoid"

### Clear cached model to refresh memory and build new model for training ###
keras.backend.clear_session() # Clear cached model
model = keras.Model(inputs, outputs) # Build new keras model
model.summary() # Print out model summary

model.compile("adam", "binary_crossentropy", metrics=["accuracy"]) # Compile built model with "adam", "binary_crossentropy", and metrics=["accuracy"]
history = model.fit(x_train, y_train, batch_size=64, epochs=10, validation_data=(x_val, y_val)) # Train the compiled model using model.fit() with batch_size=64, epochs=10, and validation_data=(x_val, y_val)

import matplotlib.pyplot as plt

loss = history.history['loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = range(len(loss))

plt.title("Scenario 2 Training and Validation Accuracy")
plt.plot(epochs, acc, "-b", label="Training Accuracy")
plt.plot(epochs, val_acc, "-r", label="Validation Accuracy")
plt.show()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None)]            0
#
#  embedding (Embedding)       (None, None, 128)         128000
#
#  lstm (LSTM)                 (None, None, 128)         131584
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 391,297
# Trainable params: 391,297
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 23s 50ms/step - loss: 0.4706 - accuracy: 0.7685 - val_loss: 0.3944 - val_accuracy: 0.8217
# Epoch 2/10
# 391/391 [==============================] - 8s 21ms/step - loss: 0.3794 - accuracy: 0.8305 - val_loss: 0.3870 - val_accuracy: 0.8215
# Epoch 3/10
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3514 - accuracy: 0.8430 - val_loss: 0.3612 - val_accuracy: 0.8362
# Epoch 4/10
# 391/391 [==============================] - 7s 19ms/step - loss: 0.3253 - accuracy: 0.8577 - val_loss: 0.3683 - val_accuracy: 0.8389
# Epoch 5/10
# 391/391 [==============================] - 8s 19ms/step - loss: 0.3087 - accuracy: 0.8672 - val_loss: 0.3608 - val_accuracy: 0.8429
# Epoch 6/10
# 391/391 [==============================] - 8s 19ms/step - loss: 0.2875 - accuracy: 0.8772 - val_loss: 0.3865 - val_accuracy: 0.8329
# Epoch 7/10
# 391/391 [==============================] - 7s 19ms/step - loss: 0.2711 - accuracy: 0.8860 - val_loss: 0.3627 - val_accuracy: 0.8390
# Epoch 8/10
# 391/391 [==============================] - 7s 19ms/step - loss: 0.2581 - accuracy: 0.8930 - val_loss: 0.3733 - val_accuracy: 0.8389
# Epoch 9/10
# 391/391 [==============================] - 7s 17ms/step - loss: 0.2411 - accuracy: 0.9003 - val_loss: 0.3870 - val_accuracy: 0.8323
# Epoch 10/10
# 391/391 [==============================] - 7s 17ms/step - loss: 0.2236 - accuracy: 0.9086 - val_loss: 0.4021 - val_accuracy: 0.8334

# %% [markdown]
# **Scenario 2 Training/Validation Accuracy plots over epochs plot inserted with Markdown mode**
#
# ![scenario2.JPG](data:image/jpeg;base64,...)

# %%
########################### Scenario 3 ###########################
##################################################################

### Set random seed to ensure deterministic results ###
import os
seed_value = 1
os.environ['PYTHONHASHSEED']=str(seed_value)
def reset_random_seeds():
   tf.random.set_seed(seed_value)
   np.random.seed(seed_value)
   random.seed(seed_value)

reset_random_seeds() # randomly set initial data

max_features = 1000 # Only consider the top 1k words
maxlen = 200 # Only consider the first 200 words of each movie review

### Model design with Embedding and LSTM layers ####
inputs = keras.Input(shape=(None,), dtype="int32") # This is an easy way to set an adaptive length for input sequence
x = layers.Embedding(max_features, 128)(inputs) # Embed data in a 128-dimensional vector
x = layers.LSTM(128, return_sequences=True )(x) # Add 1st layer of LSTM with 128 hidden states (aka units); set return_sequences=true.
x = layers.LSTM(128)(x) # Add 2nd layer of LSTM with 128 hidden states (aka units)
outputs = layers.Dense(1, activation="sigmoid")(x) # Add a classifier with units=1 and activation="sigmoid"

### Clear cached model to refresh memory and build new model for training ###
keras.backend.clear_session() # Clear cached model
model = keras.Model(inputs, outputs) # Build new keras model
model.summary() # Print out model summary

model.compile("adam", "binary_crossentropy", metrics=["accuracy"]) # Compile built model with "adam", "binary_crossentropy", and metrics=["accuracy"]
model.fit(x_train, y_train, batch_size=64, epochs=10, validation_data=(x_val, y_val)) # Train the compiled model using model.fit() with batch_size=64, epochs=10, and validation_data=(x_val, y_val)

import matplotlib.pyplot as plt

loss = history.history['loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = range(len(loss))

plt.title("Scenario 3 Training and Validation Accuracy")
plt.plot(epochs, acc, "-b", label="Training Accuracy")
plt.plot(epochs, val_acc, "-r", label="Validation Accuracy")
plt.show()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None)]            0
#
#  embedding (Embedding)       (None, None, 128)         128000
#
#  lstm (LSTM)                 (None, None, 128)         131584
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 391,297
# Trainable params: 391,297
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 21s 43ms/step - loss: 0.4706 - accuracy: 0.7689 - val_loss: 0.3948 - val_accuracy: 0.8215
# Epoch 2/10
# 391/391 [==============================] - 7s 18ms/step - loss: 0.3804 - accuracy: 0.8303 - val_loss: 0.3943 - val_accuracy: 0.8183
# Epoch 3/10
# 391/391 [==============================] - 7s 19ms/step - loss: 0.3519 - accuracy: 0.8440 - val_loss: 0.3601 - val_accuracy: 0.8376
# Epoch 4/10
# 391/391 [==============================] - 7s 17ms/step - loss: 0.3253 - accuracy: 0.8582 - val_loss: 0.3617 - val_accuracy: 0.8414
# Epoch 5/10
# 391/391 [==============================] - 8s 19ms/step - loss: 0.3087 - accuracy: 0.8681 - val_loss: 0.3611 - val_accuracy: 0.8434
# Epoch 6/10
# 391/391 [==============================] - 7s 18ms/step - loss: 0.2944 - accuracy: 0.8740 - val_loss: 0.4081 - val_accuracy: 0.8240
# Epoch 7/10
# 391/391 [==============================] - 7s 17ms/step - loss: 0.2761 - accuracy: 0.8836 - val_loss: 0.3664 - val_accuracy: 0.8388
# Epoch 8/10
# 391/391 [==============================] - 8s 20ms/step - loss: 0.2621 - accuracy: 0.8900 - val_loss: 0.3803 - val_accuracy: 0.8418
# Epoch 9/10
# 391/391 [==============================] - 6s 16ms/step - loss: 0.2421 - accuracy: 0.8998 - val_loss: 0.3829 - val_accuracy: 0.8333
# Epoch 10/10
# 391/391 [==============================] - 8s 19ms/step - loss: 0.2227 - accuracy: 0.9100 - val_loss: 0.4061 - val_accuracy: 0.8333

# %% [markdown]
# **Scenario 3 Training/Validation Accuracy plots over epochs plot inserted with Markdown mode**
#
# ![scenario3.JPG](data:image/jpeg;base64,...)
